# %%
# https://spotipy.readthedocs.io/en/2.19.0/

# install spotipy
# As google colab starts each session like a new computer, we must install this each time
# If you are working on your local machine, you only need to install once
# !pip install spotipy --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting spotipy
#   Downloading spotipy-2.20.0-py3-none-any.whl (27 kB)
# Collecting requests>=2.25.0
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 951 kB/s
# Collecting redis>=3.5.3
#   Downloading redis-4.3.4-py3-none-any.whl (246 kB)
#      |████████████████████████████████| 246 kB 10.7 MB/s
# Collecting urllib3>=1.26.0
#   Downloading urllib3-1.26.12-py2.py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 45.5 MB/s
# Requirement already satisfied: six>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spotipy) (1.15.0)
# Requirement already satisfied: packaging>=20.4 in /usr/local/lib/python3.7/dist-packages (from redis>=3.5.3->spotipy) (21.3)
# Collecting deprecated>=1.2.3
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from redis>=3.5.3->spotipy) (4.1.1)
# Requirement already satisfied: async-timeout>=4.0.2 in /usr/local/lib/python3.7/dist-packages (from redis>=3.5.3->spotipy) (4.0.2)
# Requirement already satisfied: importlib-metadata>=1.0 in /usr/local/lib/python3.7/dist-packages (from redis>=3.5.3->spotipy) (4.12.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.7/dist-packages (from deprecated>=1.2.3->redis>=3.5.3->spotipy) (1.14.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.0->redis>=3.5.3->spotipy) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.4->redis>=3.5.3->spotipy) (3.0.9)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25.0->spotipy) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25.0->spotipy) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25.0->spotipy) (2.10)
# Installing collected packages: urllib3, deprecated, requests, redis, spotipy
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# Successfully installed deprecated-1.2.13 redis-4.3.4 requests-2.28.1 spotipy-2.20.0 urllib3-1.26.12

# %%
import pandas as pd

# %% [markdown]
# ## Requests
#
# The requests library is the de facto standard for making HTTP requests in Python. It abstracts the complexities of making requests behind a beautiful, simple API so that you can focus on interacting with services and consuming data in your application.
#
# https://docs.python-requests.org/en/latest/
#
# When we make a request, we are normally returned a number - this number represents whether we received the information we wanted or not. If you get a number that you don't understand, these cats will help you: https://http.cat/
#
# More often than not you'll receive:
#
# 200: Success!
#
# 401: Unauthorized client error status: lack of valid authentication credentials
#
# 403: The server understood the request but refuses to authorize it

# %%
import requests

google = requests.get("https://developers.google.com")
print("Google:", google.status_code)

NBA = requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
print("NBA:", NBA.status_code) 

rotten_tomato = requests.get("http://api.rottentomatoes.com/api/public/v1.0/lists/movies/box_office.json")
print("Rotten Tomatoes:", rotten_tomato.status_code)
# Out:
# Google: 200
# NBA: 401
# Rotten Tomatoes: 403

# %% [markdown]
# ## JSON

# %% [markdown]
# ### Intro - making a request and viewing the JSON
#
# https://docs.python.org/3/library/json.html
#
# Since its inception, JSON has quickly become the de facto standard for information exchange. JSON supports primitive types, like strings and numbers, as well as nested lists and objects. It looks like nested python dictionaries:
#
# `{"firstname": "Harry",
# "lastname": "Noah",
# "city": "Berlin",
# "dogs": [{"name": "rover", "breed": "labrador"}, {"name": "pip", "breed": "spaniel"}],
# "cars": "none"}`

# %%
import json

# Make the request
response = requests.get("https://jsonplaceholder.typicode.com/todos")

# %%
# Check the HTTP code
response
# Out:
# <Response [200]>

# %%
# Example of how a JSON looks

# View API response as a JSON
response.json()

# %% [markdown]
# ### GitHub API - Accessing the data in the JSON
#
# Now that we know
# - what an API is
# - how to request  information from one (requests)
# - how the information will be delivered to us (json)
#
# Let's look how we can use this information. We will first look at how we can access particular values with the Json. Then we will look at a couple of methods to make a dataframe from the JSON.
#
# Github has many APIs. Here we'll look at a couple

# %%
# Very basic API (a string returned)

# GitHub's Zen API produces a new inspirational phrase every 30 second
# Run this cell again in 30 second to see a different output

resp = requests.get("https://api.github.com/zen")
resp.text
# Out:
# 'Keep it logically awesome.'

# %%
# More complex API (a large json returned)

# Github's Event API shows the events that power the various activity streams on the site
# In other words, what's happening on Github, who's updating what?

response = requests.get('https://api.github.com/events')
github_response = response.json()
github_response

# %%
# How many events are we looking at?
len(github_response)
# Out:
# 30

# %%
# What are the keys in the 1st event
github_response[0].keys()
# Out:
# dict_keys(['id', 'type', 'actor', 'repo', 'payload', 'public', 'created_at'])

# %%
# We can see that 'repo' is another subdictionary
# What are the keys in the value of 'repo'
github_response[0]['repo'].keys()
# Out:
# dict_keys(['id', 'name', 'url'])

# %%
# What's the value for the key 'name' in 'repo'
github_response[0]['repo']['name']
# Out:
# 'xowallets/Q9KcYbjUKo'

# %% [markdown]
# #### Transforming a JSON into a DataFrame

# %% [markdown]
# ##### Option 1: pd.DataFrame()

# %%
# turn it into a pandas dataframe
pd.DataFrame(github_response)
# Out:
#              id                    type  \
# 0   24390537021             CreateEvent
# 1   24390537089        PullRequestEvent
# 2   24390537096        PullRequestEvent
# 3   24390536974               PushEvent
# 4   24390537071               PushEvent
# 5   24390536997               PushEvent
# 6   24390537053               PushEvent
# 7   24390536960             CreateEvent
# 8   24390537011        PullRequestEvent
# 9   24390537015             CreateEvent
# 10  24390537057             CreateEvent
# 11  24390536964               PushEvent
# 12  24390536971               PushEvent
# 13  24390536962               PushEvent
# 14  24390536996               PushEvent
# 15  24390536975               PushEvent
# 16  24390536944               PushEvent
# 17  24390537007             CreateEvent
# 18  24390536956             CreateEvent
# 19  24390536988               PushEvent
# 20  24390536965               PushEvent
# 21  24390536977              WatchEvent
# 22  24390536928               PushEvent
# 23  24390536981               PushEvent
# 24  24390536968        PullRequestEvent
# 25  24390536856               PushEvent
# 26  24390536868               PushEvent
# 27  24390536871  PullRequestReviewEvent
# 28  24390536901  PullRequestReviewEvent
# 29  24390536889             CreateEvent
#
#                                                 actor  \
# 0   {'id': 114884843, 'login': 'xowallets', 'displ...
# 1   {'id': 5615666, 'login': 'jko314', 'display_lo...
# 2   {'id': 84767360, 'login': 'dhthinh7', 'display...
# 3   {'id': 13166525, 'login': 'fredericobormann', ...
# 4   {'id': 113664282, 'login': 'Lamech74', 'displa...
# 5   {'id': 79056677, 'login': 'n0eyes', 'display_l...
# 6   {'id': 105224534, 'login': 'Emmyrald', 'displa...
# 7   {'id': 114422033, 'login': 'PGSLOTTH888', 'dis...
# 8   {'id': 22329677, 'login': 'christocarr', 'disp...
# 9   {'id': 112966868, 'login': 'fedorks', 'display...
# 10  {'id': 114462098, 'login': 'uftd222', 'display...
# 11  {'id': 41898282, 'login': 'github-actions[bot]...
# 12  {'id': 18015381, 'login': 'emeagenciadigital',...
# 13  {'id': 69772023, 'login': 'henriqueramosqs', '...
# 14  {'id': 80479622, 'login': 'MixedMachine', 'dis...
# 15  {'id': 9378568, 'login': 'quentinneyraud', 'di...
# 16  {'id': 100294262, 'login': 'Princelet', 'displ...
# 17  {'id': 114894405, 'login': 'fixin4488', 'displ...
# 18  {'id': 115020711, 'login': 'Ashu-006', 'displa...
# 19  {'id': 50427116, 'login': 'volmen3', 'display_...
# 20  {'id': 110507766, 'login': 'Benio10ebon', 'dis...
# 21  {'id': 75264701, 'login': 'zhihanii', 'display...
# 22  {'id': 85910626, 'login': 'Angie-Santos', 'dis...
# 23  {'id': 47728478, 'login': 'srabin1', 'display_...
# 24  {'id': 31506564, 'login': 'geirolz', 'display_...
# 25  {'id': 32125575, 'login': 'Nelnaji', 'display_...
# 26  {'id': 71453807, 'login': 'MrRhuezzler', 'disp...
# 27  {'id': 28307960, 'login': 'aimemalaika', 'disp...
# 28  {'id': 8710621, 'login': 'wyb1', 'display_logi...
# 29  {'id': 115017603, 'login': 'IsabelArellano', '...
#
#                                                  repo  \
# 0   {'id': 545543190, 'name': 'xowallets/Q9KcYbjUK...
# 1   {'id': 374737509, 'name': 'Terracotta-OSS/dso'...
# 2   {'id': 489880536, 'name': 'dhthinh7/React', 'u...
# 3   {'id': 210604976, 'name': 'lawandorga/lawandor...
# 4   {'id': 545511580, 'name': 'Lamech74/alx-zero_d...
# 5   {'id': 516495228, 'name': 'n0eyes/Packman-Clie...
# 6   {'id': 545468766, 'name': 'Emmyrald/alx-zero_d...
# 7   {'id': 545543069, 'name': 'PGSLOTTH888/lEr2jKj...
# 8   {'id': 137716163, 'name': 'christocarr/contact...
# 9   {'id': 545543193, 'name': 'fedorks/HomeWork6_0...
# 10  {'id': 545543023, 'name': 'uftd222/HQu72hpS6v'...
# 11  {'id': 353534898, 'name': 'brochjad/pub_hofs',...
# 12  {'id': 539266541, 'name': 'emeagenciadigital/s...
# 13  {'id': 541621608, 'name': 'henriqueramosqs/Fir...
# 14  {'id': 537693711, 'name': 'MixedMachine/Simple...
# 15  {'id': 318271605, 'name': 'quentinneyraud/nuxt...
# 16  {'id': 539500967, 'name': 'Princelet/Car_Pract...
# 17  {'id': 545543192, 'name': 'fixin4488/XhTH1v4kx...
# 18  {'id': 545543191, 'name': 'Ashu-006/Happy-Birt...
# 19  {'id': 510503271, 'name': 'volmen3/SPHinXsys-s...
# 20  {'id': 545535157, 'name': 'Benio10ebon/Fnf-vs-...
# 21  {'id': 140687430, 'name': 'dcloudio/uni-app', ...
# 22  {'id': 528519601, 'name': 'amappola7/social-ne...
# 23  {'id': 543694492, 'name': 'srabin1/starter-web...
# 24  {'id': 363132059, 'name': 'geirolz/fp-microser...
# 25  {'id': 544908185, 'name': 'Nelnaji/Himara', 'u...
# 26  {'id': 296377890, 'name': 'MrRhuezzler/Program...
# 27  {'id': 542663289, 'name': 'henrycode460/myblog...
# 28  {'id': 117377862, 'name': 'gardener/gardener',...
# 29  {'id': 545510093, 'name': 'IsabelArellano/Alet...
#
#                                               payload  public  \
# 0   {'ref': None, 'ref_type': 'repository', 'maste...    True
# 1   {'action': 'closed', 'number': 89, 'pull_reque...    True
# 2   {'action': 'closed', 'number': 3, 'pull_reques...    True
# 3   {'push_id': 11222157390, 'size': 1, 'distinct_...    True
# 4   {'push_id': 11222157436, 'size': 1, 'distinct_...    True
# 5   {'push_id': 11222157387, 'size': 6, 'distinct_...    True
# 6   {'push_id': 11222157469, 'size': 2, 'distinct_...    True
# 7   {'ref': 'master', 'ref_type': 'branch', 'maste...    True
# 8   {'action': 'closed', 'number': 38, 'pull_reque...    True
# 9   {'ref': None, 'ref_type': 'repository', 'maste...    True
# 10  {'ref': 'master', 'ref_type': 'branch', 'maste...    True
# 11  {'push_id': 11222157403, 'size': 1, 'distinct_...    True
# 12  {'push_id': 11222157400, 'size': 1, 'distinct_...    True
# 13  {'push_id': 11222157418, 'size': 1, 'distinct_...    True
# 14  {'push_id': 11222157422, 'size': 1, 'distinct_...    True
# 15  {'push_id': 11222157404, 'size': 1, 'distinct_...    True
# 16  {'push_id': 11222157391, 'size': 1, 'distinct_...    True
# 17  {'ref': None, 'ref_type': 'repository', 'maste...    True
# 18  {'ref': None, 'ref_type': 'repository', 'maste...    True
# 19  {'push_id': 11222157424, 'size': 1, 'distinct_...    True
# 20  {'push_id': 11222157405, 'size': 1, 'distinct_...    True
# 21                              {'action': 'started'}    True
# 22  {'push_id': 11222157369, 'size': 1, 'distinct_...    True
# 23  {'push_id': 11222157412, 'size': 1, 'distinct_...    True
# 24  {'action': 'closed', 'number': 221, 'pull_requ...    True
# 25  {'push_id': 11222157366, 'size': 1, 'distinct_...    True
# 26  {'push_id': 11222157359, 'size': 1, 'distinct_...    True
# 27  {'action': 'created', 'review': {'id': 1130123...    True
# 28  {'action': 'created', 'review': {'id': 1130123...    True
# 29  {'ref': 'Carla', 'ref_type': 'branch', 'master...    True
#
#               created_at                                                org
# 0   2022-10-04T14:55:12Z                                                NaN
# 1   2022-10-04T14:55:12Z  {'id': 4680389, 'login': 'Terracotta-OSS', 'gr...
# 2   2022-10-04T14:55:12Z                                                NaN
# 3   2022-10-04T14:55:12Z  {'id': 81813394, 'login': 'lawandorga', 'grava...
# 4   2022-10-04T14:55:12Z                                                NaN
# 5   2022-10-04T14:55:12Z                                                NaN
# 6   2022-10-04T14:55:12Z                                                NaN
# 7   2022-10-04T14:55:12Z                                                NaN
# 8   2022-10-04T14:55:12Z                                                NaN
# 9   2022-10-04T14:55:12Z                                                NaN
# 10  2022-10-04T14:55:12Z                                                NaN
# 11  2022-10-04T14:55:12Z                                                NaN
# 12  2022-10-04T14:55:12Z                                                NaN
# 13  2022-10-04T14:55:12Z                                                NaN
# 14  2022-10-04T14:55:12Z                                                NaN
# 15  2022-10-04T14:55:12Z                                                NaN
# 16  2022-10-04T14:55:12Z                                                NaN
# 17  2022-10-04T14:55:12Z                                                NaN
# 18  2022-10-04T14:55:12Z                                                NaN
# 19  2022-10-04T14:55:12Z                                                NaN
# 20  2022-10-04T14:55:12Z                                                NaN
# 21  2022-10-04T14:55:12Z  {'id': 5485517, 'login': 'dcloudio', 'gravatar...
# 22  2022-10-04T14:55:12Z                                                NaN
# 23  2022-10-04T14:55:12Z                                                NaN
# 24  2022-10-04T14:55:12Z                                                NaN
# 25  2022-10-04T14:55:12Z                                                NaN
# 26  2022-10-04T14:55:12Z                                                NaN
# 27  2022-10-04T14:55:12Z                                                NaN
# 28  2022-10-04T14:55:12Z  {'id': 33683699, 'login': 'gardener', 'gravata...
# 29  2022-10-04T14:55:12Z                                                NaN

# %% [markdown]
# ##### Option 2: pd.json_normalize()
# You may notice above that many columns still contain dictionaries as values. We can correct this using json_normalize()

# %%
#https://pandas.pydata.org/docs/reference/api/pandas.json_normalize.html

pd.json_normalize(github_response)
# Out:
#              id                    type  public            created_at  \
# 0   24390537021             CreateEvent    True  2022-10-04T14:55:12Z
# 1   24390537089        PullRequestEvent    True  2022-10-04T14:55:12Z
# 2   24390537096        PullRequestEvent    True  2022-10-04T14:55:12Z
# 3   24390536974               PushEvent    True  2022-10-04T14:55:12Z
# 4   24390537071               PushEvent    True  2022-10-04T14:55:12Z
# 5   24390536997               PushEvent    True  2022-10-04T14:55:12Z
# 6   24390537053               PushEvent    True  2022-10-04T14:55:12Z
# 7   24390536960             CreateEvent    True  2022-10-04T14:55:12Z
# 8   24390537011        PullRequestEvent    True  2022-10-04T14:55:12Z
# 9   24390537015             CreateEvent    True  2022-10-04T14:55:12Z
# 10  24390537057             CreateEvent    True  2022-10-04T14:55:12Z
# 11  24390536964               PushEvent    True  2022-10-04T14:55:12Z
# 12  24390536971               PushEvent    True  2022-10-04T14:55:12Z
# 13  24390536962               PushEvent    True  2022-10-04T14:55:12Z
# 14  24390536996               PushEvent    True  2022-10-04T14:55:12Z
# 15  24390536975               PushEvent    True  2022-10-04T14:55:12Z
# 16  24390536944               PushEvent    True  2022-10-04T14:55:12Z
# 17  24390537007             CreateEvent    True  2022-10-04T14:55:12Z
# 18  24390536956             CreateEvent    True  2022-10-04T14:55:12Z
# 19  24390536988               PushEvent    True  2022-10-04T14:55:12Z
# 20  24390536965               PushEvent    True  2022-10-04T14:55:12Z
# 21  24390536977              WatchEvent    True  2022-10-04T14:55:12Z
# 22  24390536928               PushEvent    True  2022-10-04T14:55:12Z
# 23  24390536981               PushEvent    True  2022-10-04T14:55:12Z
# 24  24390536968        PullRequestEvent    True  2022-10-04T14:55:12Z
# 25  24390536856               PushEvent    True  2022-10-04T14:55:12Z
# 26  24390536868               PushEvent    True  2022-10-04T14:55:12Z
# 27  24390536871  PullRequestReviewEvent    True  2022-10-04T14:55:12Z
# 28  24390536901  PullRequestReviewEvent    True  2022-10-04T14:55:12Z
# 29  24390536889             CreateEvent    True  2022-10-04T14:55:12Z
#
#      actor.id          actor.login actor.display_login actor.gravatar_id  \
# 0   114884843            xowallets           xowallets
# 1     5615666               jko314              jko314
# 2    84767360             dhthinh7            dhthinh7
# 3    13166525     fredericobormann    fredericobormann
# 4   113664282             Lamech74            Lamech74
# 5    79056677               n0eyes              n0eyes
# 6   105224534             Emmyrald            Emmyrald
# 7   114422033          PGSLOTTH888         PGSLOTTH888
# 8    22329677          christocarr         christocarr
# 9   112966868              fedorks             fedorks
# 10  114462098              uftd222             uftd222
# 11   41898282  github-actions[bot]      github-actions
# 12   18015381    emeagenciadigital   emeagenciadigital
# 13   69772023      henriqueramosqs     henriqueramosqs
# 14   80479622         MixedMachine        MixedMachine
# 15    9378568       quentinneyraud      quentinneyraud
# 16  100294262            Princelet           Princelet
# 17  114894405            fixin4488           fixin4488
# 18  115020711             Ashu-006            Ashu-006
# 19   50427116              volmen3             volmen3
# 20  110507766          Benio10ebon         Benio10ebon
# 21   75264701             zhihanii            zhihanii
# 22   85910626         Angie-Santos        Angie-Santos
# 23   47728478              srabin1             srabin1
# 24   31506564              geirolz             geirolz
# 25   32125575              Nelnaji             Nelnaji
# 26   71453807          MrRhuezzler         MrRhuezzler
# 27   28307960          aimemalaika         aimemalaika
# 28    8710621                 wyb1                wyb1
# 29  115017603       IsabelArellano      IsabelArellano
#
#                                            actor.url  \
# 0             https://api.github.com/users/xowallets
# 1                https://api.github.com/users/jko314
# 2              https://api.github.com/users/dhthinh7
# 3      https://api.github.com/users/fredericobormann
# 4              https://api.github.com/users/Lamech74
# 5                https://api.github.com/users/n0eyes
# 6              https://api.github.com/users/Emmyrald
# 7           https://api.github.com/users/PGSLOTTH888
# 8           https://api.github.com/users/christocarr
# 9               https://api.github.com/users/fedorks
# 10              https://api.github.com/users/uftd222
# 11  https://api.github.com/users/github-actions[bot]
# 12    https://api.github.com/users/emeagenciadigital
# 13      https://api.github.com/users/henriqueramosqs
# 14         https://api.github.com/users/MixedMachine
# 15       https://api.github.com/users/quentinneyraud
# 16            https://api.github.com/users/Princelet
# 17            https://api.github.com/users/fixin4488
# 18             https://api.github.com/users/Ashu-006
# 19              https://api.github.com/users/volmen3
# 20          https://api.github.com/users/Benio10ebon
# 21             https://api.github.com/users/zhihanii
# 22         https://api.github.com/users/Angie-Santos
# 23              https://api.github.com/users/srabin1
# 24              https://api.github.com/users/geirolz
# 25              https://api.github.com/users/Nelnaji
# 26          https://api.github.com/users/MrRhuezzler
# 27          https://api.github.com/users/aimemalaika
# 28                 https://api.github.com/users/wyb1
# 29       https://api.github.com/users/IsabelArellano
#
#                                      actor.avatar_url  ...  \
# 0   https://avatars.githubusercontent.com/u/114884...  ...
# 1    https://avatars.githubusercontent.com/u/5615666?  ...
# 2   https://avatars.githubusercontent.com/u/84767360?  ...
# 3   https://avatars.githubusercontent.com/u/13166525?  ...
# 4   https://avatars.githubusercontent.com/u/113664...  ...
# 5   https://avatars.githubusercontent.com/u/79056677?  ...
# 6   https://avatars.githubusercontent.com/u/105224...  ...
# 7   https://avatars.githubusercontent.com/u/114422...  ...
# 8   https://avatars.githubusercontent.com/u/22329677?  ...
# 9   https://avatars.githubusercontent.com/u/112966...  ...
# 10  https://avatars.githubusercontent.com/u/114462...  ...
# 11  https://avatars.githubusercontent.com/u/41898282?  ...
# 12  https://avatars.githubusercontent.com/u/18015381?  ...
# 13  https://avatars.githubusercontent.com/u/69772023?  ...
# 14  https://avatars.githubusercontent.com/u/80479622?  ...
# 15   https://avatars.githubusercontent.com/u/9378568?  ...
# 16  https://avatars.githubusercontent.com/u/100294...  ...
# 17  https://avatars.githubusercontent.com/u/114894...  ...
# 18  https://avatars.githubusercontent.com/u/115020...  ...
# 19  https://avatars.githubusercontent.com/u/50427116?  ...
# 20  https://avatars.githubusercontent.com/u/110507...  ...
# 21  https://avatars.githubusercontent.com/u/75264701?  ...
# 22  https://avatars.githubusercontent.com/u/85910626?  ...
# 23  https://avatars.githubusercontent.com/u/47728478?  ...
# 24  https://avatars.githubusercontent.com/u/31506564?  ...
# 25  https://avatars.githubusercontent.com/u/32125575?  ...
# 26  https://avatars.githubusercontent.com/u/71453807?  ...
# 27  https://avatars.githubusercontent.com/u/28307960?  ...
# 28   https://avatars.githubusercontent.com/u/8710621?  ...
# 29  https://avatars.githubusercontent.com/u/115017...  ...
#
#     payload.review.user.site_admin  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# 5                              NaN
# 6                              NaN
# 7                              NaN
# 8                              NaN
# 9                              NaN
# 10                             NaN
# 11                             NaN
# 12                             NaN
# 13                             NaN
# 14                             NaN
# 15                             NaN
# 16                             NaN
# 17                             NaN
# 18                             NaN
# 19                             NaN
# 20                             NaN
# 21                             NaN
# 22                             NaN
# 23                             NaN
# 24                             NaN
# 25                             NaN
# 26                             NaN
# 27                           False
# 28                           False
# 29                             NaN
#
#                                   payload.review.body  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27  Hi @henrycode460 , \r\n\r\nYour project is com...
# 28
# 29                                                NaN
#
#                     payload.review.commit_id payload.review.submitted_at  \
# 0                                        NaN                         NaN
# 1                                        NaN                         NaN
# 2                                        NaN                         NaN
# 3                                        NaN                         NaN
# 4                                        NaN                         NaN
# 5                                        NaN                         NaN
# 6                                        NaN                         NaN
# 7                                        NaN                         NaN
# 8                                        NaN                         NaN
# 9                                        NaN                         NaN
# 10                                       NaN                         NaN
# 11                                       NaN                         NaN
# 12                                       NaN                         NaN
# 13                                       NaN                         NaN
# 14                                       NaN                         NaN
# 15                                       NaN                         NaN
# 16                                       NaN                         NaN
# 17                                       NaN                         NaN
# 18                                       NaN                         NaN
# 19                                       NaN                         NaN
# 20                                       NaN                         NaN
# 21                                       NaN                         NaN
# 22                                       NaN                         NaN
# 23                                       NaN                         NaN
# 24                                       NaN                         NaN
# 25                                       NaN                         NaN
# 26                                       NaN                         NaN
# 27  8e2573d93d4415e729a0864026a762a179e2e0eb        2022-10-04T14:55:11Z
# 28  bf4ff3a6bfd2c0d0f9389fa46479e79dc409430d        2022-10-04T14:55:11Z
# 29                                       NaN                         NaN
#
#    payload.review.state                            payload.review.html_url  \
# 0                   NaN                                                NaN
# 1                   NaN                                                NaN
# 2                   NaN                                                NaN
# 3                   NaN                                                NaN
# 4                   NaN                                                NaN
# 5                   NaN                                                NaN
# 6                   NaN                                                NaN
# 7                   NaN                                                NaN
# 8                   NaN                                                NaN
# 9                   NaN                                                NaN
# 10                  NaN                                                NaN
# 11                  NaN                                                NaN
# 12                  NaN                                                NaN
# 13                  NaN                                                NaN
# 14                  NaN                                                NaN
# 15                  NaN                                                NaN
# 16                  NaN                                                NaN
# 17                  NaN                                                NaN
# 18                  NaN                                                NaN
# 19                  NaN                                                NaN
# 20                  NaN                                                NaN
# 21                  NaN                                                NaN
# 22                  NaN                                                NaN
# 23                  NaN                                                NaN
# 24                  NaN                                                NaN
# 25                  NaN                                                NaN
# 26                  NaN                                                NaN
# 27             approved  https://github.com/henrycode460/myblog/pull/5#...
# 28             approved  https://github.com/gardener/gardener/pull/6771...
# 29                  NaN                                                NaN
#
#                       payload.review.pull_request_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27  https://api.github.com/repos/henrycode460/mybl...
# 28  https://api.github.com/repos/gardener/gardener...
# 29                                                NaN
#
#    payload.review.author_association  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# 5                                NaN
# 6                                NaN
# 7                                NaN
# 8                                NaN
# 9                                NaN
# 10                               NaN
# 11                               NaN
# 12                               NaN
# 13                               NaN
# 14                               NaN
# 15                               NaN
# 16                               NaN
# 17                               NaN
# 18                               NaN
# 19                               NaN
# 20                               NaN
# 21                               NaN
# 22                               NaN
# 23                               NaN
# 24                               NaN
# 25                               NaN
# 26                               NaN
# 27                              NONE
# 28                            MEMBER
# 29                               NaN
#
#                       payload.review._links.html.href  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27  https://github.com/henrycode460/myblog/pull/5#...
# 28  https://github.com/gardener/gardener/pull/6771...
# 29                                                NaN
#
#               payload.review._links.pull_request.href
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27  https://api.github.com/repos/henrycode460/mybl...
# 28  https://api.github.com/repos/gardener/gardener...
# 29                                                NaN
#
# [30 rows x 389 columns]

# %% [markdown]
# #### Selecting only certain values by iterating with a for loop
#
# If we only want to select certain parts of the JSON
# - Option 1: make a DataFrame and drop the rest
# - Option 2: Use a for loop to exract only the required information

# %%
# login - first value
github_response[0]['actor']['login']
# Out:
# 'xowallets'

# %%
# repo - first value
github_response[0]['repo']['name']
# Out:
# 'xowallets/Q9KcYbjUKo'

# %%
# event_type - first value
github_response[0]['type']
# Out:
# 'CreateEvent'

# %%
# https://www.w3schools.com/python/python_for_loops.asp
# https://www.w3schools.com/python/ref_func_range.asp

# empty lists that the loop will fill with values
login = []
repo = []
event_type = []

for i in range(len(github_response)):
    # add the login value to the login list
    login.append(github_response[i]['actor']['login'])
    # add the repo name to the repo list
    repo.append(github_response[i]['repo']['name'])
    # add the event type to the event_type list
    event_type.append(github_response[i]['type'])

# %%
# Let's have a look at the login list
login
# Out:
# ['xowallets',
#  'jko314',
#  'dhthinh7',
#  'fredericobormann',
#  'Lamech74',
#  'n0eyes',
#  'Emmyrald',
#  'PGSLOTTH888',
#  'christocarr',
#  'fedorks',
#  'uftd222',
#  'github-actions[bot]',
#  'emeagenciadigital',
#  'henriqueramosqs',
#  'MixedMachine',
#  'quentinneyraud',
#  'Princelet',
#  'fixin4488',
#  'Ashu-006',
#  'volmen3',
#  'Benio10ebon',
#  'zhihanii',
#  'Angie-Santos',
#  'srabin1',
#  'geirolz',
#  'Nelnaji',
#  'MrRhuezzler',
#  'aimemalaika',
#  'wyb1',
#  'IsabelArellano']

# %%
# Let's have a look at the repo list
repo
# Out:
# ['xowallets/Q9KcYbjUKo',
#  'Terracotta-OSS/dso',
#  'dhthinh7/React',
#  'lawandorga/lawandorga-backend-service',
#  'Lamech74/alx-zero_day',
#  'n0eyes/Packman-Client',
#  'Emmyrald/alx-zero_day',
#  'PGSLOTTH888/lEr2jKjoSA',
#  'christocarr/contacts',
#  'fedorks/HomeWork6_031022',
#  'uftd222/HQu72hpS6v',
#  'brochjad/pub_hofs',
#  'emeagenciadigital/static-eme',
#  'henriqueramosqs/Fire-Emblem',
#  'MixedMachine/SimpleAuthBackend',
#  'quentinneyraud/nuxt-templates',
#  'Princelet/Car_Practice',
#  'fixin4488/XhTH1v4kxm',
#  'Ashu-006/Happy-Birthday-Card',
#  'volmen3/SPHinXsys-source',
#  'Benio10ebon/Fnf-vs-Os-Vigilantes-Psych-engine-port',
#  'dcloudio/uni-app',
#  'amappola7/social-network',
#  'srabin1/starter-web',
#  'geirolz/fp-microservice',
#  'Nelnaji/Himara',
#  'MrRhuezzler/Programs',
#  'henrycode460/myblog',
#  'gardener/gardener',
#  'IsabelArellano/Aletheia']

# %%
# Let's have a look at the event_type list
event_type
# Out:
# ['CreateEvent',
#  'PullRequestEvent',
#  'PullRequestEvent',
#  'PushEvent',
#  'PushEvent',
#  'PushEvent',
#  'PushEvent',
#  'CreateEvent',
#  'PullRequestEvent',
#  'CreateEvent',
#  'CreateEvent',
#  'PushEvent',
#  'PushEvent',
#  'PushEvent',
#  'PushEvent',
#  'PushEvent',
#  'PushEvent',
#  'CreateEvent',
#  'CreateEvent',
#  'PushEvent',
#  'PushEvent',
#  'WatchEvent',
#  'PushEvent',
#  'PushEvent',
#  'PullRequestEvent',
#  'PushEvent',
#  'PushEvent',
#  'PullRequestReviewEvent',
#  'PullRequestReviewEvent',
#  'CreateEvent']

# %% [markdown]
# ### Intenational Space Station API - just another cool API
#
# Send a simple `get` request to know where the ISS is right now.
#
# Docs here: http://open-notify.org/Open-Notify-API/ISS-Location-Now/

# %%
url = "http://api.open-notify.org/iss-now.json"

# %%
response = requests.get(url)

# %%
response.json()
# Out:
# {'message': 'success',
#  'timestamp': 1664895612,
#  'iss_position': {'latitude': '-8.5030', 'longitude': '102.8478'}}

# %% [markdown]
# ## Spotipy - now that you know all about APIs, let's use that knowledge on something fun
#
# Spotify has an API that allows users to gather information about songs and even interact with other users and playlists. To make their usage in Python easier, someone created `spotipy`, a library with some convenient functions to send requests and collect data.
#
# Create / log into an Spotify account (https://developer.spotify.com/dashboard/login) and follow these steps (only the "Register your App" section): https://developer.spotify.com/documentation/general/guides/authorization/app-settings/

# %% [markdown]
# #### Authentification
#
# With most APIs we need to autheticate ourself. This is often done with a username and password. You will likely use a different username and password for most APIs, so make sure you're using a password manager, or keeping everything written down somewhere safe.
#
# If ever you'd like more information about spotipy [here are the docs](https://spotipy.readthedocs.io/en/2.16.1/)

# %%
# import libraries
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(
    client_id="82d10cbeab244ba885a29af43becd014",
    client_secret="b23ecbf78eb743b38161dae226870f4c"))

# %%
sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(
    client_id="4f3178f82dd54838a2e06c9d4003a726",
    client_secret="25b63863e2674da1a8a914ff62b53d04"))

# %% [markdown]
# #### Searching songs with 'queries' with `sp.search`
#
# This method allows you to find songs with using Spotify's search engine. That's convenient when you don't have the exact "id" of a song.

# %%
# search for 'Lady Gaga', restricted to the first 10 results

results = sp.search(q="Lady Gaga", limit = 10)

# %% [markdown]
# Explore the object returned by the request. As it's a dictionary (with nested dictionaries inside), using `.keys` is a great way to see what's in there:

# %%
results.keys()
# Out:
# dict_keys(['tracks'])

# %%
# only one key makes it seem like there'll be many subdictionaries, let's delve deeper
results["tracks"].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %% [markdown]
# This is the url of your request:

# %%
# You can play the track by pasting the url in your browser

# We can explore further by adding keys one after the other

results["tracks"]["href"]
# Out:
# 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=0&limit=10'

# %% [markdown]
# This is the name of the first song returned by the API:

# %%
results["tracks"]["items"][0]["name"]
# Out:
# 'Bad Romance'

# %% [markdown]
# As one song can have many artists, the artists are returned as a list: note the square brackets.

# %%
results["tracks"]["items"][0]["artists"]
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#   'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#   'id': '1HY2Jd0NmPuamShAr6KMms',
#   'name': 'Lady Gaga',
#   'type': 'artist',
#   'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}]

# %% [markdown]
# There are some other interesting features contained in the search results:

# %%
# https://developer.spotify.com/documentation/web-api/reference/#/operations/get-several-tracks
# The popularity of the track. The value will be between 0 and 100, with 100 being the most popular.

results["tracks"]["items"][0]["popularity"]
# Out:
# 83

# %% [markdown]
# This is how Spotify identifies individual songs: with a Uniform Resource Identifier  or `uri`. (the `id` and the `url` are also ways to identify each song uniquely).

# %%
results["tracks"]["items"][0]["uri"]
# Out:
# 'spotify:track:0SiywuOBRcynK0uKGWdCnn'

# %% [markdown]
# Here we look for 10 songs by the Red Hot Chilli Peppers and store the `uri` of the songs and their names.

# %%
# send request and store the response
red_hot = sp.search(q="Red hot chili peppers", limit=10)

# initialize empty lists that we will fill with information from our loop
list_of_uri = []
list_of_song_names = []

# iterate through the "items" (the songs) 
# and append the "uri" and the "name" to the lists we created
for item in red_hot["tracks"]["items"]:
    list_of_uri.append(item["uri"])
    list_of_song_names.append(item["name"])

# print results
print(list_of_uri)
print("\n")
print(list_of_song_names)
# Out:
# ['spotify:track:3d9DChrdc6BOeFsbrZ3Is0', 'spotify:track:3xJu5hrOU9OvFQSGLQiwQS', 'spotify:track:64BbK9SFKH2jk86U3dGj2P', 'spotify:track:3ZOEytgrvLwQaqXreDs2Jx', 'spotify:track:4dzbGvxqQ1DsF6m6RUlPwg', 'spotify:track:48UPSzbZjgc449aqz8bxox', 'spotify:track:10Nmj3JCNoMeBQ87uw5j8k', 'spotify:track:1G391cbiT3v3Cywg8T7DM1', 'spotify:track:0Kojfmpnf0A2yC1zyv39Zx', 'spotify:track:2aibwv5hGXSgw7Yru8IYTO']
#
#
# ['Under the Bridge', 'Anthony Kiedis', 'Otherside', "Can't Stop", 'Pedigree', 'Californication', 'Dani California', 'Scar Tissue', 'Buried Alive', 'Snow (Hey Oh)']

# %% [markdown]
# #### Searching multiple artists
#
# Here we first create a list of artists we want to gather songs from. Then we iterate through them and append the results into a big list called `results`.

# %%
artists = ["Red hot chili peppers", "SCARR", "Whitney Houston"]

# %%
results = []

for artist in artists:
    results.append(sp.search(q=artist, limit=10))

# %%
# Let's look at the second element in the results list
results[1]
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=SCARR&type=track&offset=0&limit=10',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4fxd5Ee7UefO4CUXgwJ7IP'},
#        'href': 'https://api.spotify.com/v1/artists/4fxd5Ee7UefO4CUXgwJ7IP',
#        'id': '4fxd5Ee7UefO4CUXgwJ7IP',
#        'name': 'Giveon',
#        'type': 'artist',
#        'uri': 'spotify:artist:4fxd5Ee7UefO4CUXgwJ7IP'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/64LkgCfNbLqjclQYCTid8L'},
#      'href': 'https://api.spotify.com/v1/albums/64LkgCfNbLqjclQYCTid8L',
#      'id': '64LkgCfNbLqjclQYCTid8L',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732739e569d6b6d0e0abc8cd9b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022739e569d6b6d0e0abc8cd9b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512739e569d6b6d0e0abc8cd9b',
#        'width': 64}],
#      'name': 'Give Or Take',
#      'release_date': '2022-06-24',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:64LkgCfNbLqjclQYCTid8L'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4fxd5Ee7UefO4CUXgwJ7IP'},
#       'href': 'https://api.spotify.com/v1/artists/4fxd5Ee7UefO4CUXgwJ7IP',
#       'id': '4fxd5Ee7UefO4CUXgwJ7IP',
#       'name': 'Giveon',
#       'type': 'artist',
#       'uri': 'spotify:artist:4fxd5Ee7UefO4CUXgwJ7IP'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 178264,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM12107667'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5PSYn0XVImstXPFFDtajEK'},
#     'href': 'https://api.spotify.com/v1/tracks/5PSYn0XVImstXPFFDtajEK',
#     'id': '5PSYn0XVImstXPFFDtajEK',
#     'is_local': False,
#     'name': 'Scarred',
#     'popularity': 70,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5f5fd3a9a6be18dd8141103415eedbf894c57e1b?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:5PSYn0XVImstXPFFDtajEK'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5f7VJjfbwm532GiveGC0ZK'},
#        'href': 'https://api.spotify.com/v1/artists/5f7VJjfbwm532GiveGC0ZK',
#        'id': '5f7VJjfbwm532GiveGC0ZK',
#        'name': 'Lil Baby',
#        'type': 'artist',
#        'uri': 'spotify:artist:5f7VJjfbwm532GiveGC0ZK'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1ynyQdPQiXdYJNQEDL1S3d'},
#      'href': 'https://api.spotify.com/v1/albums/1ynyQdPQiXdYJNQEDL1S3d',
#      'id': '1ynyQdPQiXdYJNQEDL1S3d',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f46a9ad551acbdab8f72fd89',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f46a9ad551acbdab8f72fd89',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f46a9ad551acbdab8f72fd89',
#        'width': 64}],
#      'name': 'My Turn',
#      'release_date': '2020-02-28',
#      'release_date_precision': 'day',
#      'total_tracks': 20,
#      'type': 'album',
#      'uri': 'spotify:album:1ynyQdPQiXdYJNQEDL1S3d'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5f7VJjfbwm532GiveGC0ZK'},
#       'href': 'https://api.spotify.com/v1/artists/5f7VJjfbwm532GiveGC0ZK',
#       'id': '5f7VJjfbwm532GiveGC0ZK',
#       'name': 'Lil Baby',
#       'type': 'artist',
#       'uri': 'spotify:artist:5f7VJjfbwm532GiveGC0ZK'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 197529,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUG12000034'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7ge7BHazYbVKi8qyZUX1Bm'},
#     'href': 'https://api.spotify.com/v1/tracks/7ge7BHazYbVKi8qyZUX1Bm',
#     'id': '7ge7BHazYbVKi8qyZUX1Bm',
#     'is_local': False,
#     'name': 'Emotionally Scarred',
#     'popularity': 74,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1b66d3f03d14fcba6bd24a297e7bddb98c0bc09b?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:7ge7BHazYbVKi8qyZUX1Bm'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Tv1UzQAvn0v0hKTxisXnR'},
#        'href': 'https://api.spotify.com/v1/artists/3Tv1UzQAvn0v0hKTxisXnR',
#        'id': '3Tv1UzQAvn0v0hKTxisXnR',
#        'name': 'Kaito Shoma',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Tv1UzQAvn0v0hKTxisXnR'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/2ledyuziz6YjLK5Dw483Oc'},
#        'href': 'https://api.spotify.com/v1/artists/2ledyuziz6YjLK5Dw483Oc',
#        'id': '2ledyuziz6YjLK5Dw483Oc',
#        'name': 'DJ Paul',
#        'type': 'artist',
#        'uri': 'spotify:artist:2ledyuziz6YjLK5Dw483Oc'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5kkVPwCLmdkqaSQpptZtXj'},
#        'href': 'https://api.spotify.com/v1/artists/5kkVPwCLmdkqaSQpptZtXj',
#        'id': '5kkVPwCLmdkqaSQpptZtXj',
#        'name': 'Kingpin Skinny Pimp',
#        'type': 'artist',
#        'uri': 'spotify:artist:5kkVPwCLmdkqaSQpptZtXj'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/04QDTmdKMoDHqqFaHEoDVP'},
#      'href': 'https://api.spotify.com/v1/albums/04QDTmdKMoDHqqFaHEoDVP',
#      'id': '04QDTmdKMoDHqqFaHEoDVP',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27390eb8cc7792233599046a61f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0290eb8cc7792233599046a61f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485190eb8cc7792233599046a61f',
#        'width': 64}],
#      'name': 'Scary Garry',
#      'release_date': '2021-01-04',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:04QDTmdKMoDHqqFaHEoDVP'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Tv1UzQAvn0v0hKTxisXnR'},
#       'href': 'https://api.spotify.com/v1/artists/3Tv1UzQAvn0v0hKTxisXnR',
#       'id': '3Tv1UzQAvn0v0hKTxisXnR',
#       'name': 'Kaito Shoma',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Tv1UzQAvn0v0hKTxisXnR'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2ledyuziz6YjLK5Dw483Oc'},
#       'href': 'https://api.spotify.com/v1/artists/2ledyuziz6YjLK5Dw483Oc',
#       'id': '2ledyuziz6YjLK5Dw483Oc',
#       'name': 'DJ Paul',
#       'type': 'artist',
#       'uri': 'spotify:artist:2ledyuziz6YjLK5Dw483Oc'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5kkVPwCLmdkqaSQpptZtXj'},
#       'href': 'https://api.spotify.com/v1/artists/5kkVPwCLmdkqaSQpptZtXj',
#       'id': '5kkVPwCLmdkqaSQpptZtXj',
#       'name': 'Kingpin Skinny Pimp',
#       'type': 'artist',
#       'uri': 'spotify:artist:5kkVPwCLmdkqaSQpptZtXj'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 99748,
#     'explicit': True,
#     'external_ids': {'isrc': 'QM4TW2104033'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/658QJ4p8WcbT3O7iWLpO1D'},
#     'href': 'https://api.spotify.com/v1/tracks/658QJ4p8WcbT3O7iWLpO1D',
#     'id': '658QJ4p8WcbT3O7iWLpO1D',
#     'is_local': False,
#     'name': 'Scary Garry',
#     'popularity': 77,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8a939d56e968ebf4ca079d60fc95629f7744e05d?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:658QJ4p8WcbT3O7iWLpO1D'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4IprNlQiJZUUJhDl0fL2SL'},
#        'href': 'https://api.spotify.com/v1/artists/4IprNlQiJZUUJhDl0fL2SL',
#        'id': '4IprNlQiJZUUJhDl0fL2SL',
#        'name': 'Quando Rondo',
#        'type': 'artist',
#        'uri': 'spotify:artist:4IprNlQiJZUUJhDl0fL2SL'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2s19QcF1PIILzRfS6Jjni3'},
#      'href': 'https://api.spotify.com/v1/albums/2s19QcF1PIILzRfS6Jjni3',
#      'id': '2s19QcF1PIILzRfS6Jjni3',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27301a870253a90ff8c53dce16e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0201a870253a90ff8c53dce16e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485101a870253a90ff8c53dce16e',
#        'width': 64}],
#      'name': 'From the Neighborhood to the Stage',
#      'release_date': '2019-05-10',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:2s19QcF1PIILzRfS6Jjni3'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4IprNlQiJZUUJhDl0fL2SL'},
#       'href': 'https://api.spotify.com/v1/artists/4IprNlQiJZUUJhDl0fL2SL',
#       'id': '4IprNlQiJZUUJhDl0fL2SL',
#       'name': 'Quando Rondo',
#       'type': 'artist',
#       'uri': 'spotify:artist:4IprNlQiJZUUJhDl0fL2SL'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 207000,
#     'explicit': True,
#     'external_ids': {'isrc': 'USAT21901934'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5CFvscpivObLfIVQtHyQxE'},
#     'href': 'https://api.spotify.com/v1/tracks/5CFvscpivObLfIVQtHyQxE',
#     'id': '5CFvscpivObLfIVQtHyQxE',
#     'is_local': False,
#     'name': 'Scarred From Love',
#     'popularity': 55,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6b259dc2c4a3a3bb393f7a1d557c0a1c9d50723f?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:5CFvscpivObLfIVQtHyQxE'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1z7cTlp6ckvLvVoZBMMNMQ'},
#        'href': 'https://api.spotify.com/v1/artists/1z7cTlp6ckvLvVoZBMMNMQ',
#        'id': '1z7cTlp6ckvLvVoZBMMNMQ',
#        'name': 'swoozydolphin',
#        'type': 'artist',
#        'uri': 'spotify:artist:1z7cTlp6ckvLvVoZBMMNMQ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/38jv2P71u8Xp4VFJMzAasI'},
#      'href': 'https://api.spotify.com/v1/albums/38jv2P71u8Xp4VFJMzAasI',
#      'id': '38jv2P71u8Xp4VFJMzAasI',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27345484c4cebd679a9aff90dcc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0245484c4cebd679a9aff90dcc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485145484c4cebd679a9aff90dcc',
#        'width': 64}],
#      'name': 'swzgaze',
#      'release_date': '2021-04-16',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:38jv2P71u8Xp4VFJMzAasI'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1z7cTlp6ckvLvVoZBMMNMQ'},
#       'href': 'https://api.spotify.com/v1/artists/1z7cTlp6ckvLvVoZBMMNMQ',
#       'id': '1z7cTlp6ckvLvVoZBMMNMQ',
#       'name': 'swoozydolphin',
#       'type': 'artist',
#       'uri': 'spotify:artist:1z7cTlp6ckvLvVoZBMMNMQ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 99001,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZES82132753'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/21hQmHixsf32jwujwGBThB'},
#     'href': 'https://api.spotify.com/v1/tracks/21hQmHixsf32jwujwGBThB',
#     'id': '21hQmHixsf32jwujwGBThB',
#     'is_local': False,
#     'name': 'SCARR',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9f8f4365db02921e90191b642c96079b6f8d8107?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:21hQmHixsf32jwujwGBThB'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6HWC3HweNpFwBU00BNVCCq'},
#        'href': 'https://api.spotify.com/v1/artists/6HWC3HweNpFwBU00BNVCCq',
#        'id': '6HWC3HweNpFwBU00BNVCCq',
#        'name': 'Luke',
#        'type': 'artist',
#        'uri': 'spotify:artist:6HWC3HweNpFwBU00BNVCCq'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7lccXBuQ92VhUbWM2nPQmo'},
#      'href': 'https://api.spotify.com/v1/albums/7lccXBuQ92VhUbWM2nPQmo',
#      'id': '7lccXBuQ92VhUbWM2nPQmo',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27388e50ceec20521397129c929',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0288e50ceec20521397129c929',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485188e50ceec20521397129c929',
#        'width': 64}],
#      'name': 'Scandalous - The All Star Compilation',
#      'release_date': '2014',
#      'release_date_precision': 'year',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:7lccXBuQ92VhUbWM2nPQmo'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6HWC3HweNpFwBU00BNVCCq'},
#       'href': 'https://api.spotify.com/v1/artists/6HWC3HweNpFwBU00BNVCCq',
#       'id': '6HWC3HweNpFwBU00BNVCCq',
#       'name': 'Luke',
#       'type': 'artist',
#       'uri': 'spotify:artist:6HWC3HweNpFwBU00BNVCCq'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/12FHARd9fY0Tu0ila4Ua25'},
#       'href': 'https://api.spotify.com/v1/artists/12FHARd9fY0Tu0ila4Ua25',
#       'id': '12FHARd9fY0Tu0ila4Ua25',
#       'name': 'Trick Daddy',
#       'type': 'artist',
#       'uri': 'spotify:artist:12FHARd9fY0Tu0ila4Ua25'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 206053,
#     'explicit': True,
#     'external_ids': {'isrc': 'USJ3V1822275'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0NXA8wKGM6eRgLzpJXanGL'},
#     'href': 'https://api.spotify.com/v1/tracks/0NXA8wKGM6eRgLzpJXanGL',
#     'id': '0NXA8wKGM6eRgLzpJXanGL',
#     'is_local': False,
#     'name': 'Scarred',
#     'popularity': 43,
#     'preview_url': 'https://p.scdn.co/mp3-preview/19253f53cd15966de16b50c3b0a1a5e6ba43211b?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:0NXA8wKGM6eRgLzpJXanGL'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/579LsvZcRVKtToYjS0tkKz'},
#        'href': 'https://api.spotify.com/v1/artists/579LsvZcRVKtToYjS0tkKz',
#        'id': '579LsvZcRVKtToYjS0tkKz',
#        'name': 'Big Scarr',
#        'type': 'artist',
#        'uri': 'spotify:artist:579LsvZcRVKtToYjS0tkKz'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/59pMTqaKusiZtVLLuwx6Ut'},
#      'href': 'https://api.spotify.com/v1/albums/59pMTqaKusiZtVLLuwx6Ut',
#      'id': '59pMTqaKusiZtVLLuwx6Ut',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273cff8f5cfb89de46767f202f6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02cff8f5cfb89de46767f202f6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851cff8f5cfb89de46767f202f6',
#        'width': 64}],
#      'name': 'Big Grim Reaper: The Return',
#      'release_date': '2022-02-25',
#      'release_date_precision': 'day',
#      'total_tracks': 30,
#      'type': 'album',
#      'uri': 'spotify:album:59pMTqaKusiZtVLLuwx6Ut'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/579LsvZcRVKtToYjS0tkKz'},
#       'href': 'https://api.spotify.com/v1/artists/579LsvZcRVKtToYjS0tkKz',
#       'id': '579LsvZcRVKtToYjS0tkKz',
#       'name': 'Big Scarr',
#       'type': 'artist',
#       'uri': 'spotify:artist:579LsvZcRVKtToYjS0tkKz'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2n3qi31tlGzSvWhOyr4wT8'},
#       'href': 'https://api.spotify.com/v1/artists/2n3qi31tlGzSvWhOyr4wT8',
#       'id': '2n3qi31tlGzSvWhOyr4wT8',
#       'name': 'Quezz Ruthless',
#       'type': 'artist',
#       'uri': 'spotify:artist:2n3qi31tlGzSvWhOyr4wT8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 161426,
#     'explicit': True,
#     'external_ids': {'isrc': 'USAT22200536'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4qXUGU3aEhxHoIoa8REBTP'},
#     'href': 'https://api.spotify.com/v1/tracks/4qXUGU3aEhxHoIoa8REBTP',
#     'id': '4qXUGU3aEhxHoIoa8REBTP',
#     'is_local': False,
#     'name': 'MJ (feat. Quezz Ruthless)',
#     'popularity': 63,
#     'preview_url': 'https://p.scdn.co/mp3-preview/425e1cc5cbb599d22ea0a5237126af1ac43e2740?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:4qXUGU3aEhxHoIoa8REBTP'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/579LsvZcRVKtToYjS0tkKz'},
#        'href': 'https://api.spotify.com/v1/artists/579LsvZcRVKtToYjS0tkKz',
#        'id': '579LsvZcRVKtToYjS0tkKz',
#        'name': 'Big Scarr',
#        'type': 'artist',
#        'uri': 'spotify:artist:579LsvZcRVKtToYjS0tkKz'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
# ...
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 190037,
#     'explicit': True,
#     'external_ids': {'isrc': 'USAT22006621'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/12DNxMLgOdNTjChoV9ynNY'},
#     'href': 'https://api.spotify.com/v1/tracks/12DNxMLgOdNTjChoV9ynNY',
#     'id': '12DNxMLgOdNTjChoV9ynNY',
#     'is_local': False,
#     'name': 'SoIcyBoyz 2 (feat. Pooh Shiesty, Foogiano & Tay Keith)',
#     'popularity': 62,
#     'preview_url': 'https://p.scdn.co/mp3-preview/57d6a1e314a199be18e80895cb7053fe311726e3?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track_number': 17,
#     'type': 'track',
#     'uri': 'spotify:track:12DNxMLgOdNTjChoV9ynNY'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1sQHD0DIlJ8oElG6XMO2P3'},
#        'href': 'https://api.spotify.com/v1/artists/1sQHD0DIlJ8oElG6XMO2P3',
#        'id': '1sQHD0DIlJ8oElG6XMO2P3',
#        'name': 'Backdoor Sam',
#        'type': 'artist',
#        'uri': 'spotify:artist:1sQHD0DIlJ8oElG6XMO2P3'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/579LsvZcRVKtToYjS0tkKz'},
#        'href': 'https://api.spotify.com/v1/artists/579LsvZcRVKtToYjS0tkKz',
#        'id': '579LsvZcRVKtToYjS0tkKz',
#        'name': 'Big Scarr',
#        'type': 'artist',
#        'uri': 'spotify:artist:579LsvZcRVKtToYjS0tkKz'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7aNeo8IwbTpv3sfFNgBiiV'},
#      'href': 'https://api.spotify.com/v1/albums/7aNeo8IwbTpv3sfFNgBiiV',
#      'id': '7aNeo8IwbTpv3sfFNgBiiV',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27328d9631eac5ae7dafb55a333',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0228d9631eac5ae7dafb55a333',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485128d9631eac5ae7dafb55a333',
#        'width': 64}],
#      'name': "Scarred Baby's",
#      'release_date': '2022-02-22',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:7aNeo8IwbTpv3sfFNgBiiV'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1sQHD0DIlJ8oElG6XMO2P3'},
#       'href': 'https://api.spotify.com/v1/artists/1sQHD0DIlJ8oElG6XMO2P3',
#       'id': '1sQHD0DIlJ8oElG6XMO2P3',
#       'name': 'Backdoor Sam',
#       'type': 'artist',
#       'uri': 'spotify:artist:1sQHD0DIlJ8oElG6XMO2P3'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/579LsvZcRVKtToYjS0tkKz'},
#       'href': 'https://api.spotify.com/v1/artists/579LsvZcRVKtToYjS0tkKz',
#       'id': '579LsvZcRVKtToYjS0tkKz',
#       'name': 'Big Scarr',
#       'type': 'artist',
#       'uri': 'spotify:artist:579LsvZcRVKtToYjS0tkKz'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 193210,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUYG1415638'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/57SN8XoR7SWUqWeRMCYAgm'},
#     'href': 'https://api.spotify.com/v1/tracks/57SN8XoR7SWUqWeRMCYAgm',
#     'id': '57SN8XoR7SWUqWeRMCYAgm',
#     'is_local': False,
#     'name': "Scarred Baby's",
#     'popularity': 41,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b4ea741dc948988daa25de195350d64952385da6?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:57SN8XoR7SWUqWeRMCYAgm'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/579LsvZcRVKtToYjS0tkKz'},
#        'href': 'https://api.spotify.com/v1/artists/579LsvZcRVKtToYjS0tkKz',
#        'id': '579LsvZcRVKtToYjS0tkKz',
#        'name': 'Big Scarr',
#        'type': 'artist',
#        'uri': 'spotify:artist:579LsvZcRVKtToYjS0tkKz'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/59pMTqaKusiZtVLLuwx6Ut'},
#      'href': 'https://api.spotify.com/v1/albums/59pMTqaKusiZtVLLuwx6Ut',
#      'id': '59pMTqaKusiZtVLLuwx6Ut',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273cff8f5cfb89de46767f202f6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02cff8f5cfb89de46767f202f6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851cff8f5cfb89de46767f202f6',
#        'width': 64}],
#      'name': 'Big Grim Reaper: The Return',
#      'release_date': '2022-02-25',
#      'release_date_precision': 'day',
#      'total_tracks': 30,
#      'type': 'album',
#      'uri': 'spotify:album:59pMTqaKusiZtVLLuwx6Ut'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/579LsvZcRVKtToYjS0tkKz'},
#       'href': 'https://api.spotify.com/v1/artists/579LsvZcRVKtToYjS0tkKz',
#       'id': '579LsvZcRVKtToYjS0tkKz',
#       'name': 'Big Scarr',
#       'type': 'artist',
#       'uri': 'spotify:artist:579LsvZcRVKtToYjS0tkKz'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4DdkRBBYG6Yk9Ka8tdJ9BW'},
#       'href': 'https://api.spotify.com/v1/artists/4DdkRBBYG6Yk9Ka8tdJ9BW',
#       'id': '4DdkRBBYG6Yk9Ka8tdJ9BW',
#       'name': 'Offset',
#       'type': 'artist',
#       'uri': 'spotify:artist:4DdkRBBYG6Yk9Ka8tdJ9BW'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 202783,
#     'explicit': True,
#     'external_ids': {'isrc': 'USAT22200532'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2Hl9mZVT3fXMq4NwDa16sM'},
#     'href': 'https://api.spotify.com/v1/tracks/2Hl9mZVT3fXMq4NwDa16sM',
#     'id': '2Hl9mZVT3fXMq4NwDa16sM',
#     'is_local': False,
#     'name': 'Fantasy (feat. Offset)',
#     'popularity': 62,
#     'preview_url': 'https://p.scdn.co/mp3-preview/dfc0edded68b84bbb62cba6462355b6edbd973b3?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:2Hl9mZVT3fXMq4NwDa16sM'}],
#   'limit': 10,
#   'next': 'https://api.spotify.com/v1/search?query=SCARR&type=track&offset=10&limit=10',
#   'offset': 0,
#   'previous': None,
#   'total': 8241}}

# %% [markdown]
# We can iterate through the `results` list and get just the names of all the songs:

# %%
song_names = []

for result in results:
    for item in result["tracks"]["items"]:
        song_names.append(item["name"])

# %%
song_names
# Out:
# ['Under the Bridge',
#  'Anthony Kiedis',
#  'Otherside',
#  "Can't Stop",
#  'Pedigree',
#  'Californication',
#  'Dani California',
#  'Scar Tissue',
#  'Buried Alive',
#  'Snow (Hey Oh)',
#  'Scarred',
#  'Emotionally Scarred',
#  'Scary Garry',
#  'Scarred From Love',
#  'SCARR',
#  'Scarred',
#  'MJ (feat. Quezz Ruthless)',
#  'SoIcyBoyz 2 (feat. Pooh Shiesty, Foogiano & Tay Keith)',
#  "Scarred Baby's",
#  'Fantasy (feat. Offset)',
#  'I Wanna Dance with Somebody (Who Loves Me)',
#  'I Will Always Love You',
#  'Higher Love',
#  'How Will I Know',
#  'How Will I Know',
#  'I Have Nothing',
#  'Greatest Love of All',
#  'Saving All My Love for You',
#  'You Give Good Love',
#  'Where Do Broken Hearts Go']

# %% [markdown]
# ### Playlists
#
# Using spotipy we can both build and read spotify playlists. Today we will only show you how to read information from a playlist. However, if you wish to build one, we strongly encourage you read the [documentation](https://spotipy.readthedocs.io/en/2.19.0/) and explore further.

# %%
my_playlist = sp.user_playlist_tracks(user="spotify", playlist_id="spotify:playlist:0ce6Rmxf7QXroqa1wzjWY8")

# %% [markdown]
# Extract songs ID from a playlist

# %%
my_playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/0ce6Rmxf7QXroqa1wzjWY8/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2021-09-22T07:34:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#     'href': 'https://api.spotify.com/v1/users/gperdigo',
#     'id': 'gperdigo',
#     'type': 'user',
#     'uri': 'spotify:user:gperdigo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/579T5fNgfbDetyamUTAetw'},
#        'href': 'https://api.spotify.com/v1/artists/579T5fNgfbDetyamUTAetw',
#        'id': '579T5fNgfbDetyamUTAetw',
#        'name': 'S+C+A+R+R',
#        'type': 'artist',
#        'uri': 'spotify:artist:579T5fNgfbDetyamUTAetw'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5ZwTPVgvwIMxJh2GAdsaaP'},
#      'href': 'https://api.spotify.com/v1/albums/5ZwTPVgvwIMxJh2GAdsaaP',
#      'id': '5ZwTPVgvwIMxJh2GAdsaaP',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27331df83ec065ed0a42cc82670',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0231df83ec065ed0a42cc82670',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485131df83ec065ed0a42cc82670',
#        'width': 64}],
#      'name': 'You\'re the One (From "I Lost My Body")',
#      'release_date': '2019-10-31',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5ZwTPVgvwIMxJh2GAdsaaP'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/579T5fNgfbDetyamUTAetw'},
#       'href': 'https://api.spotify.com/v1/artists/579T5fNgfbDetyamUTAetw',
#       'id': '579T5fNgfbDetyamUTAetw',
#       'name': 'S+C+A+R+R',
#       'type': 'artist',
#       'uri': 'spotify:artist:579T5fNgfbDetyamUTAetw'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 167986,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'FR6F31902770'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5Tnx4R7Gwj1LZsfssfzchh'},
#     'href': 'https://api.spotify.com/v1/tracks/5Tnx4R7Gwj1LZsfssfzchh',
#     'id': '5Tnx4R7Gwj1LZsfssfzchh',
#     'is_local': False,
#     'name': 'You\'re the One - From "I Lost My Body"',
#     'popularity': 36,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d42e003a7ba7293394d75af67584659dccce2012?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5Tnx4R7Gwj1LZsfssfzchh'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:35:32Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#     'href': 'https://api.spotify.com/v1/users/gperdigo',
#     'id': 'gperdigo',
#     'type': 'user',
#     'uri': 'spotify:user:gperdigo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5wFXmYsg3KFJ8BDsQudJ4f'},
#        'href': 'https://api.spotify.com/v1/artists/5wFXmYsg3KFJ8BDsQudJ4f',
#        'id': '5wFXmYsg3KFJ8BDsQudJ4f',
#        'name': 'Manchester Orchestra',
#        'type': 'artist',
#        'uri': 'spotify:artist:5wFXmYsg3KFJ8BDsQudJ4f'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4hruYceqit29o6m4arpAql'},
#      'href': 'https://api.spotify.com/v1/albums/4hruYceqit29o6m4arpAql',
#      'id': '4hruYceqit29o6m4arpAql',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736827146a676dafc0357fa665',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026827146a676dafc0357fa665',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516827146a676dafc0357fa665',
#        'width': 64}],
#      'name': 'A Black Mile To The Surface',
#      'release_date': '2017-07-28',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:4hruYceqit29o6m4arpAql'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5wFXmYsg3KFJ8BDsQudJ4f'},
#       'href': 'https://api.spotify.com/v1/artists/5wFXmYsg3KFJ8BDsQudJ4f',
#       'id': '5wFXmYsg3KFJ8BDsQudJ4f',
#       'name': 'Manchester Orchestra',
#       'type': 'artist',
#       'uri': 'spotify:artist:5wFXmYsg3KFJ8BDsQudJ4f'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 328933,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USC4R1702133'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5eKfpH2dQ7FltCqb7LWEGJ'},
#     'href': 'https://api.spotify.com/v1/tracks/5eKfpH2dQ7FltCqb7LWEGJ',
#     'id': '5eKfpH2dQ7FltCqb7LWEGJ',
#     'is_local': False,
#     'name': 'The Alien',
#     'popularity': 47,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:5eKfpH2dQ7FltCqb7LWEGJ'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:35:42Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#     'href': 'https://api.spotify.com/v1/users/gperdigo',
#     'id': 'gperdigo',
#     'type': 'user',
#     'uri': 'spotify:user:gperdigo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1rqPrJjVzB01kfoQpz6XNe'},
#        'href': 'https://api.spotify.com/v1/artists/1rqPrJjVzB01kfoQpz6XNe',
#        'id': '1rqPrJjVzB01kfoQpz6XNe',
#        'name': 'Nina & Frederik',
#        'type': 'artist',
#        'uri': 'spotify:artist:1rqPrJjVzB01kfoQpz6XNe'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/63obBSI5HlMFoawrrq8RDG'},
#      'href': 'https://api.spotify.com/v1/albums/63obBSI5HlMFoawrrq8RDG',
#      'id': '63obBSI5HlMFoawrrq8RDG',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a287436c88bfedf3892dcaea',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a287436c88bfedf3892dcaea',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a287436c88bfedf3892dcaea',
#        'width': 64}],
#      'name': 'Vintage World Nº10- EPs Collectors "Oh, Pecador" "Oh, Sinner Man"',
#      'release_date': '1958-05-06',
#      'release_date_precision': 'day',
#      'total_tracks': 4,
#      'type': 'album',
#      'uri': 'spotify:album:63obBSI5HlMFoawrrq8RDG'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1rqPrJjVzB01kfoQpz6XNe'},
#       'href': 'https://api.spotify.com/v1/artists/1rqPrJjVzB01kfoQpz6XNe',
#       'id': '1rqPrJjVzB01kfoQpz6XNe',
#       'name': 'Nina & Frederik',
#       'type': 'artist',
#       'uri': 'spotify:artist:1rqPrJjVzB01kfoQpz6XNe'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 145773,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USA560979249'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0R3OcHrzq3f8raukyZgTAc'},
#     'href': 'https://api.spotify.com/v1/tracks/0R3OcHrzq3f8raukyZgTAc',
#     'id': '0R3OcHrzq3f8raukyZgTAc',
#     'is_local': False,
#     'name': 'Oh, Pecador (Oh, Sinne Man)',
#     'popularity': 1,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d8ad67f1e113b024d90188a0015d7f53131efc9d?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0R3OcHrzq3f8raukyZgTAc'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:36:25Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#     'href': 'https://api.spotify.com/v1/users/gperdigo',
#     'id': 'gperdigo',
#     'type': 'user',
#     'uri': 'spotify:user:gperdigo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2G7QgTep5IsJHGHm1hXygD'},
#        'href': 'https://api.spotify.com/v1/artists/2G7QgTep5IsJHGHm1hXygD',
#        'id': '2G7QgTep5IsJHGHm1hXygD',
#        'name': 'Kid Francescoli',
#        'type': 'artist',
#        'uri': 'spotify:artist:2G7QgTep5IsJHGHm1hXygD'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4iII9nfzjxOYQFp8PyV6HD'},
#      'href': 'https://api.spotify.com/v1/albums/4iII9nfzjxOYQFp8PyV6HD',
#      'id': '4iII9nfzjxOYQFp8PyV6HD',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737fc1ed797a7ef1dd805b5bc5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027fc1ed797a7ef1dd805b5bc5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517fc1ed797a7ef1dd805b5bc5',
#        'width': 64}],
#      'name': 'Play Me Again',
#      'release_date': '2017-03-03',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:4iII9nfzjxOYQFp8PyV6HD'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2G7QgTep5IsJHGHm1hXygD'},
#       'href': 'https://api.spotify.com/v1/artists/2G7QgTep5IsJHGHm1hXygD',
#       'id': '2G7QgTep5IsJHGHm1hXygD',
#       'name': 'Kid Francescoli',
#       'type': 'artist',
#       'uri': 'spotify:artist:2G7QgTep5IsJHGHm1hXygD'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/63fbQTZ9yW3SUsBRYcn1Wm'},
#       'href': 'https://api.spotify.com/v1/artists/63fbQTZ9yW3SUsBRYcn1Wm',
#       'id': '63fbQTZ9yW3SUsBRYcn1Wm',
#       'name': 'Julia Minkin',
#       'type': 'artist',
#       'uri': 'spotify:artist:63fbQTZ9yW3SUsBRYcn1Wm'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 390638,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'FRP621600280'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/24upABZ8A0sAepfu91sEYr'},
#     'href': 'https://api.spotify.com/v1/tracks/24upABZ8A0sAepfu91sEYr',
#     'id': '24upABZ8A0sAepfu91sEYr',
#     'is_local': False,
#     'name': 'Moon (And It Went Like)',
#     'popularity': 67,
#     'preview_url': 'https://p.scdn.co/mp3-preview/cbdc77c2fad05ac37a494bc2976e4fed73a018f2?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track': True,
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:24upABZ8A0sAepfu91sEYr'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:36:45Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#     'href': 'https://api.spotify.com/v1/users/gperdigo',
#     'id': 'gperdigo',
#     'type': 'user',
#     'uri': 'spotify:user:gperdigo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4aEnNH9PuU1HF3TsZTru54'},
#        'href': 'https://api.spotify.com/v1/artists/4aEnNH9PuU1HF3TsZTru54',
#        'id': '4aEnNH9PuU1HF3TsZTru54',
#        'name': 'Caribou',
#        'type': 'artist',
#        'uri': 'spotify:artist:4aEnNH9PuU1HF3TsZTru54'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1NqhnYAVqlHuPG2OlgKSZy'},
#      'href': 'https://api.spotify.com/v1/albums/1NqhnYAVqlHuPG2OlgKSZy',
#      'id': '1NqhnYAVqlHuPG2OlgKSZy',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273db02bfcbd6808d71afb2a3bf',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02db02bfcbd6808d71afb2a3bf',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851db02bfcbd6808d71afb2a3bf',
#        'width': 64}],
#      'name': 'Never Come Back',
#      'release_date': '2020-01-28',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:1NqhnYAVqlHuPG2OlgKSZy'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4aEnNH9PuU1HF3TsZTru54'},
#       'href': 'https://api.spotify.com/v1/artists/4aEnNH9PuU1HF3TsZTru54',
#       'id': '4aEnNH9PuU1HF3TsZTru54',
#       'name': 'Caribou',
#       'type': 'artist',
#       'uri': 'spotify:artist:4aEnNH9PuU1HF3TsZTru54'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 305480,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'DED622000007'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7IBrKDuBlyz3vW9JFCux10'},
#     'href': 'https://api.spotify.com/v1/tracks/7IBrKDuBlyz3vW9JFCux10',
#     'id': '7IBrKDuBlyz3vW9JFCux10',
#     'is_local': False,
#     'name': 'Never Come Back',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7IBrKDuBlyz3vW9JFCux10'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:36:57Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gperdigo'},
#     'href': 'https://api.spotify.com/v1/users/gperdigo',
#     'id': 'gperdigo',
#     'type': 'user',
#     'uri': 'spotify:user:gperdigo'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6wH6iStAh4KIaWfuhf0NYM'},
#        'href': 'https://api.spotify.com/v1/artists/6wH6iStAh4KIaWfuhf0NYM',
#        'id': '6wH6iStAh4KIaWfuhf0NYM',
#        'name': 'Manu Chao',
#        'type': 'artist',
#        'uri': 'spotify:artist:6wH6iStAh4KIaWfuhf0NYM'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6sLpbLsD1LlXnlCRjt8YuE'},
#      'href': 'https://api.spotify.com/v1/albums/6sLpbLsD1LlXnlCRjt8YuE',
#      'id': '6sLpbLsD1LlXnlCRjt8YuE',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27381d487c754295e61521aadcc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0281d487c754295e61521aadcc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485181d487c754295e61521aadcc',
#        'width': 64}],
#      'name': 'Proxima Estacion : Esperanza',
#      'release_date': '2001',
#      'release_date_precision': 'year',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:6sLpbLsD1LlXnlCRjt8YuE'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6wH6iStAh4KIaWfuhf0NYM'},
#       'href': 'https://api.spotify.com/v1/artists/6wH6iStAh4KIaWfuhf0NYM',
#       'id': '6wH6iStAh4KIaWfuhf0NYM',
#       'name': 'Manu Chao',
#       'type': 'artist',
#       'uri': 'spotify:artist:6wH6iStAh4KIaWfuhf0NYM'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 114920,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'FR84R0100008'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3ecVMxkn0sJ3nlx1uS0IVN'},
#     'href': 'https://api.spotify.com/v1/tracks/3ecVMxkn0sJ3nlx1uS0IVN',
#     'id': '3ecVMxkn0sJ3nlx1uS0IVN',
#     'is_local': False,
#     'name': 'Trapped By Love',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:3ecVMxkn0sJ3nlx1uS0IVN'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:50:42Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1269546383'},
#     'href': 'https://api.spotify.com/v1/users/1269546383',
#     'id': '1269546383',
#     'type': 'user',
#     'uri': 'spotify:user:1269546383'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5v74mT11KGJqadf9sLw4dA'},
#        'href': 'https://api.spotify.com/v1/artists/5v74mT11KGJqadf9sLw4dA',
#        'id': '5v74mT11KGJqadf9sLw4dA',
#        'name': 'Cannonball Adderley',
#        'type': 'artist',
#        'uri': 'spotify:artist:5v74mT11KGJqadf9sLw4dA'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5JpHin9lKOyizuJhKxaHWp'},
#      'href': 'https://api.spotify.com/v1/albums/5JpHin9lKOyizuJhKxaHWp',
#      'id': '5JpHin9lKOyizuJhKxaHWp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27385827d636962ea87b858ab32',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0285827d636962ea87b858ab32',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485185827d636962ea87b858ab32',
#        'width': 64}],
#      'name': 'Jazz Profile: Cannonball Adderley',
#      'release_date': '1997-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:5JpHin9lKOyizuJhKxaHWp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5v74mT11KGJqadf9sLw4dA'},
#       'href': 'https://api.spotify.com/v1/artists/5v74mT11KGJqadf9sLw4dA',
#       'id': '5v74mT11KGJqadf9sLw4dA',
#       'name': 'Cannonball Adderley',
#       'type': 'artist',
#       'uri': 'spotify:artist:5v74mT11KGJqadf9sLw4dA'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 313200,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USCA29000136'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6NF8MZ2trxckVBr82pyyPt'},
#     'href': 'https://api.spotify.com/v1/tracks/6NF8MZ2trxckVBr82pyyPt',
#     'id': '6NF8MZ2trxckVBr82pyyPt',
#     'is_local': False,
#     'name': 'Mercy, Mercy, Mercy',
#     'popularity': 55,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:6NF8MZ2trxckVBr82pyyPt'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:51:02Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1269546383'},
#     'href': 'https://api.spotify.com/v1/users/1269546383',
#     'id': '1269546383',
#     'type': 'user',
#     'uri': 'spotify:user:1269546383'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ayds6VIVBx3CU5NSNCDbq'},
#        'href': 'https://api.spotify.com/v1/artists/3ayds6VIVBx3CU5NSNCDbq',
#        'id': '3ayds6VIVBx3CU5NSNCDbq',
#        'name': 'Jacques Dutronc',
#        'type': 'artist',
#        'uri': 'spotify:artist:3ayds6VIVBx3CU5NSNCDbq'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2S4mgB4hHSszPRGoYrGJ0d'},
#      'href': 'https://api.spotify.com/v1/albums/2S4mgB4hHSszPRGoYrGJ0d',
#      'id': '2S4mgB4hHSszPRGoYrGJ0d',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a28387fcc6e1c7ed11d82022',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a28387fcc6e1c7ed11d82022',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a28387fcc6e1c7ed11d82022',
#        'width': 64}],
#      'name': "L' aventurier",
#      'release_date': '1969-06-30',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:2S4mgB4hHSszPRGoYrGJ0d'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ayds6VIVBx3CU5NSNCDbq'},
#       'href': 'https://api.spotify.com/v1/artists/3ayds6VIVBx3CU5NSNCDbq',
#       'id': '3ayds6VIVBx3CU5NSNCDbq',
#       'name': 'Jacques Dutronc',
#       'type': 'artist',
#       'uri': 'spotify:artist:3ayds6VIVBx3CU5NSNCDbq'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TR',
#      'TT',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 155600,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'FRZ196900030'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6FwkZ5lYdCUh1mzI1Bhojn'},
#     'href': 'https://api.spotify.com/v1/tracks/6FwkZ5lYdCUh1mzI1Bhojn',
#     'id': '6FwkZ5lYdCUh1mzI1Bhojn',
#     'is_local': False,
#     'name': 'Le responsable',
#     'popularity': 36,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3dd3c6675f6b3ac215630f5379f7947566f8bcb5?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6FwkZ5lYdCUh1mzI1Bhojn'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:51:17Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1269546383'},
#     'href': 'https://api.spotify.com/v1/users/1269546383',
#     'id': '1269546383',
#     'type': 'user',
#     'uri': 'spotify:user:1269546383'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2AR42Ur9PcchQDtEdwkv4L'},
#        'href': 'https://api.spotify.com/v1/artists/2AR42Ur9PcchQDtEdwkv4L',
#        'id': '2AR42Ur9PcchQDtEdwkv4L',
#        'name': 'Floating Points',
#        'type': 'artist',
#        'uri': 'spotify:artist:2AR42Ur9PcchQDtEdwkv4L'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
# ...
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2adSO4KU3FDjeM1PXCRDZm'},
#      'href': 'https://api.spotify.com/v1/albums/2adSO4KU3FDjeM1PXCRDZm',
#      'id': '2adSO4KU3FDjeM1PXCRDZm',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f461bbc21a9bcec43a926973',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f461bbc21a9bcec43a926973',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f461bbc21a9bcec43a926973',
#        'width': 64}],
#      'name': 'The Business',
#      'release_date': '2020-09-16',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2adSO4KU3FDjeM1PXCRDZm'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2o5jDhtHVPhrJdv3cEQ99Z'},
#       'href': 'https://api.spotify.com/v1/artists/2o5jDhtHVPhrJdv3cEQ99Z',
#       'id': '2o5jDhtHVPhrJdv3cEQ99Z',
#       'name': 'Tiësto',
#       'type': 'artist',
#       'uri': 'spotify:artist:2o5jDhtHVPhrJdv3cEQ99Z'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 164000,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'CYA112000624'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6f3Slt0GbA2bPZlz0aIFXN'},
#     'href': 'https://api.spotify.com/v1/tracks/6f3Slt0GbA2bPZlz0aIFXN',
#     'id': '6f3Slt0GbA2bPZlz0aIFXN',
#     'is_local': False,
#     'name': 'The Business',
#     'popularity': 83,
#     'preview_url': 'https://p.scdn.co/mp3-preview/0eab33c8cf88fdd3046bd58133b6cbf2fe31773c?cid=4f3178f82dd54838a2e06c9d4003a726',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6f3Slt0GbA2bPZlz0aIFXN'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:53:47Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/not_invented_here'},
#     'href': 'https://api.spotify.com/v1/users/not_invented_here',
#     'id': 'not_invented_here',
#     'type': 'user',
#     'uri': 'spotify:user:not_invented_here'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7qmf5YAQYjfjBF9C7kkjzs'},
#        'href': 'https://api.spotify.com/v1/artists/7qmf5YAQYjfjBF9C7kkjzs',
#        'id': '7qmf5YAQYjfjBF9C7kkjzs',
#        'name': 'Johnny Hooker',
#        'type': 'artist',
#        'uri': 'spotify:artist:7qmf5YAQYjfjBF9C7kkjzs'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0kelpiZssyYlVNks8cHEth'},
#      'href': 'https://api.spotify.com/v1/albums/0kelpiZssyYlVNks8cHEth',
#      'id': '0kelpiZssyYlVNks8cHEth',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734d5ac815f4676b21c60bfdc8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024d5ac815f4676b21c60bfdc8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514d5ac815f4676b21c60bfdc8',
#        'width': 64}],
#      'name': 'Eu Vou Fazer uma Macumba Pra Te Amarrar, Maldito!',
#      'release_date': '2015-02-22',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:0kelpiZssyYlVNks8cHEth'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7qmf5YAQYjfjBF9C7kkjzs'},
#       'href': 'https://api.spotify.com/v1/artists/7qmf5YAQYjfjBF9C7kkjzs',
#       'id': '7qmf5YAQYjfjBF9C7kkjzs',
#       'name': 'Johnny Hooker',
#       'type': 'artist',
#       'uri': 'spotify:artist:7qmf5YAQYjfjBF9C7kkjzs'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 285000,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'uscgh1563538'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7uSdpAkxgB0948bW7yjjJO'},
#     'href': 'https://api.spotify.com/v1/tracks/7uSdpAkxgB0948bW7yjjJO',
#     'id': '7uSdpAkxgB0948bW7yjjJO',
#     'is_local': False,
#     'name': 'Amor Marginal',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:7uSdpAkxgB0948bW7yjjJO'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T07:53:52Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/shokoshock'},
#     'href': 'https://api.spotify.com/v1/users/shokoshock',
#     'id': 'shokoshock',
#     'type': 'user',
#     'uri': 'spotify:user:shokoshock'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0YMeriqrS3zgsX24nfY0F0'},
#        'href': 'https://api.spotify.com/v1/artists/0YMeriqrS3zgsX24nfY0F0',
#        'id': '0YMeriqrS3zgsX24nfY0F0',
#        'name': 'The Tragically Hip',
#        'type': 'artist',
#        'uri': 'spotify:artist:0YMeriqrS3zgsX24nfY0F0'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6fRGXiRnTyLLRDXpXkrK1n'},
#      'href': 'https://api.spotify.com/v1/albums/6fRGXiRnTyLLRDXpXkrK1n',
#      'id': '6fRGXiRnTyLLRDXpXkrK1n',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273eb5ebaaa20f7d208ce1caa14',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02eb5ebaaa20f7d208ce1caa14',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851eb5ebaaa20f7d208ce1caa14',
#        'width': 64}],
#      'name': 'Yer Favourites',
#      'release_date': '2005-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 37,
#      'type': 'album',
#      'uri': 'spotify:album:6fRGXiRnTyLLRDXpXkrK1n'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0YMeriqrS3zgsX24nfY0F0'},
#       'href': 'https://api.spotify.com/v1/artists/0YMeriqrS3zgsX24nfY0F0',
#       'id': '0YMeriqrS3zgsX24nfY0F0',
#       'name': 'The Tragically Hip',
#       'type': 'artist',
#       'uri': 'spotify:artist:0YMeriqrS3zgsX24nfY0F0'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 225426,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'CAM199600015'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5nC2BQzszGGkZi7cvxFzH4'},
#     'href': 'https://api.spotify.com/v1/tracks/5nC2BQzszGGkZi7cvxFzH4',
#     'id': '5nC2BQzszGGkZi7cvxFzH4',
#     'is_local': False,
#     'name': 'Ahead By A Century',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:5nC2BQzszGGkZi7cvxFzH4'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-22T13:02:30Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/vaxgmeceb7pigybrcc3fdlhiw'},
#     'href': 'https://api.spotify.com/v1/users/vaxgmeceb7pigybrcc3fdlhiw',
#     'id': 'vaxgmeceb7pigybrcc3fdlhiw',
#     'type': 'user',
#     'uri': 'spotify:user:vaxgmeceb7pigybrcc3fdlhiw'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7zsin6IgVsR1rqSRCNYDwq'},
#        'href': 'https://api.spotify.com/v1/artists/7zsin6IgVsR1rqSRCNYDwq',
#        'id': '7zsin6IgVsR1rqSRCNYDwq',
#        'name': 'Family of the Year',
#        'type': 'artist',
#        'uri': 'spotify:artist:7zsin6IgVsR1rqSRCNYDwq'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/14SCnv027L0HidHq0URIDu'},
#      'href': 'https://api.spotify.com/v1/albums/14SCnv027L0HidHq0URIDu',
#      'id': '14SCnv027L0HidHq0URIDu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731980a53c08d4911caa77d249',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021980a53c08d4911caa77d249',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511980a53c08d4911caa77d249',
#        'width': 64}],
#      'name': 'Loma Vista',
#      'release_date': '2012-07-10',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:14SCnv027L0HidHq0URIDu'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7zsin6IgVsR1rqSRCNYDwq'},
#       'href': 'https://api.spotify.com/v1/artists/7zsin6IgVsR1rqSRCNYDwq',
#       'id': '7zsin6IgVsR1rqSRCNYDwq',
#       'name': 'Family of the Year',
#       'type': 'artist',
#       'uri': 'spotify:artist:7zsin6IgVsR1rqSRCNYDwq'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 190280,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'CAN111200237'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6GRDI9suQHikFP6euIXnpq'},
#     'href': 'https://api.spotify.com/v1/tracks/6GRDI9suQHikFP6euIXnpq',
#     'id': '6GRDI9suQHikFP6euIXnpq',
#     'is_local': False,
#     'name': 'Hero',
#     'popularity': 4,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:6GRDI9suQHikFP6euIXnpq'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-09-29T14:22:09Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/8em1nqrnfspx3alyw0rz3ggn1'},
#     'href': 'https://api.spotify.com/v1/users/8em1nqrnfspx3alyw0rz3ggn1',
#     'id': '8em1nqrnfspx3alyw0rz3ggn1',
#     'type': 'user',
#     'uri': 'spotify:user:8em1nqrnfspx3alyw0rz3ggn1'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/58r1rB5t3VF5X6yXGPequV'},
#        'href': 'https://api.spotify.com/v1/artists/58r1rB5t3VF5X6yXGPequV',
#        'id': '58r1rB5t3VF5X6yXGPequV',
#        'name': 'Maverick City Music',
#        'type': 'artist',
#        'uri': 'spotify:artist:58r1rB5t3VF5X6yXGPequV'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0prxUuXzlIyjSJU9ej003n'},
#      'href': 'https://api.spotify.com/v1/albums/0prxUuXzlIyjSJU9ej003n',
#      'id': '0prxUuXzlIyjSJU9ej003n',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732176cda6fb0f4db7dbb6f1fb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022176cda6fb0f4db7dbb6f1fb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512176cda6fb0f4db7dbb6f1fb',
#        'width': 64}],
#      'name': 'Maverick City Vol. 3 Part 1',
#      'release_date': '2020-04-17',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:0prxUuXzlIyjSJU9ej003n'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/58r1rB5t3VF5X6yXGPequV'},
#       'href': 'https://api.spotify.com/v1/artists/58r1rB5t3VF5X6yXGPequV',
#       'id': '58r1rB5t3VF5X6yXGPequV',
#       'name': 'Maverick City Music',
#       'type': 'artist',
#       'uri': 'spotify:artist:58r1rB5t3VF5X6yXGPequV'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5nO7Yt0Jon48sqKR6VME4T'},
#       'href': 'https://api.spotify.com/v1/artists/5nO7Yt0Jon48sqKR6VME4T',
#       'id': '5nO7Yt0Jon48sqKR6VME4T',
#       'name': 'Joe L Barnes',
#       'type': 'artist',
#       'uri': 'spotify:artist:5nO7Yt0Jon48sqKR6VME4T'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4rc8nzClXj7sUjvsHVg6AD'},
#       'href': 'https://api.spotify.com/v1/artists/4rc8nzClXj7sUjvsHVg6AD',
#       'id': '4rc8nzClXj7sUjvsHVg6AD',
#       'name': 'Naomi Raine',
#       'type': 'artist',
#       'uri': 'spotify:artist:4rc8nzClXj7sUjvsHVg6AD'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 646239,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCAET2042835'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0aZFEiDKLK2B4gzPaGCZVm'},
#     'href': 'https://api.spotify.com/v1/tracks/0aZFEiDKLK2B4gzPaGCZVm',
#     'id': '0aZFEiDKLK2B4gzPaGCZVm',
#     'is_local': False,
#     'name': 'Promises',
#     'popularity': 2,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:0aZFEiDKLK2B4gzPaGCZVm'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 16}

# %%
my_playlist["items"][0]["track"]["uri"]
# Out:
# 'spotify:track:5Tnx4R7Gwj1LZsfssfzchh'

# %% [markdown]
# ### Audio features
#
# You can check here an explanation of the audio features [here](https://developer.spotify.com/documentation/web-api/reference/tracks/get-audio-features/)

# %%
sp.audio_features("spotify:track:6Sy9BUbgFse0n0LPA5lwy5")
# Out:
# [{'danceability': 0.528,
#   'energy': 0.965,
#   'key': 11,
#   'loudness': -7.984,
#   'mode': 0,
#   'speechiness': 0.0465,
#   'acousticness': 0.141,
#   'instrumentalness': 0.985,
#   'liveness': 0.0797,
#   'valence': 0.587,
#   'tempo': 136.065,
#   'type': 'audio_features',
#   'id': '6Sy9BUbgFse0n0LPA5lwy5',
#   'uri': 'spotify:track:6Sy9BUbgFse0n0LPA5lwy5',
#   'track_href': 'https://api.spotify.com/v1/tracks/6Sy9BUbgFse0n0LPA5lwy5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Sy9BUbgFse0n0LPA5lwy5',
#   'duration_ms': 225493,
#   'time_signature': 4}]

# %% [markdown]
# ### Creating a function that takes a song name and returns its audio features

# %%
list_of_songs = []

def song_features(human_song_title):
    # search for the song title you enter into the function, limited to the first 10 results
    results = sp.search(q=human_song_title, limit = 10)['tracks']['items']
    # create a loop, so we only select the parts of the json we need
    for i in results:
        # empty dictionary to be filled with the information below
        track_dict = {}
        # add the key artist and a corresponding value to the dictionary
        track_dict['Artist'] = i['artists'][0]['name']
        # add the key title and the corresponding value to the dictionary
        track_dict['Title'] = i['name'] 
        # add the key album and the corresponding value to the dictionary
        track_dict['Album'] = i['album']['name']
        # add the key audio description and the corresponding value to the dictionary
        track_dict['Audio Description'] = sp.audio_features(i['id'])
        # add the dictionary to the list list_of_songs
        list_of_songs.append(track_dict)
    # output list_of_songs 
    return list_of_songs

# call the function with a song to test
song_features("Under the Bridge")
# Out:
# [{'Artist': 'Red Hot Chili Peppers',
#   'Title': 'Under the Bridge',
#   'Album': 'Blood Sugar Sex Magik (Deluxe Edition)',
#   'Audio Description': [{'danceability': 0.559,
#     'energy': 0.345,
#     'key': 4,
#     'loudness': -13.496,
#     'mode': 1,
#     'speechiness': 0.0459,
#     'acousticness': 0.0576,
#     'instrumentalness': 0.000105,
#     'liveness': 0.141,
#     'valence': 0.458,
#     'tempo': 84.581,
#     'type': 'audio_features',
#     'id': '3d9DChrdc6BOeFsbrZ3Is0',
#     'uri': 'spotify:track:3d9DChrdc6BOeFsbrZ3Is0',
#     'track_href': 'https://api.spotify.com/v1/tracks/3d9DChrdc6BOeFsbrZ3Is0',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3d9DChrdc6BOeFsbrZ3Is0',
#     'duration_ms': 264307,
#     'time_signature': 4}]},
#  {'Artist': 'owlh',
#   'Title': 'Under the Bridge',
#   'Album': 'cover to cover',
#   'Audio Description': [{'danceability': 0.781,
#     'energy': 0.355,
#     'key': 9,
#     'loudness': -8.158,
#     'mode': 1,
#     'speechiness': 0.0376,
#     'acousticness': 0.471,
#     'instrumentalness': 0.878,
#     'liveness': 0.125,
#     'valence': 0.363,
#     'tempo': 131.978,
#     'type': 'audio_features',
#     'id': '1AyRpRvLwUwkXwGGuNZHmN',
#     'uri': 'spotify:track:1AyRpRvLwUwkXwGGuNZHmN',
#     'track_href': 'https://api.spotify.com/v1/tracks/1AyRpRvLwUwkXwGGuNZHmN',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1AyRpRvLwUwkXwGGuNZHmN',
#     'duration_ms': 244196,
#     'time_signature': 4}]},
#  {'Artist': 'Adele',
#   'Title': 'Water Under the Bridge',
#   'Album': '25',
#   'Audio Description': [{'danceability': 0.59,
#     'energy': 0.833,
#     'key': 5,
#     'loudness': -6.503,
#     'mode': 0,
#     'speechiness': 0.0615,
#     'acousticness': 0.0142,
#     'instrumentalness': 5.4e-06,
#     'liveness': 0.105,
#     'valence': 0.538,
#     'tempo': 94.963,
#     'type': 'audio_features',
#     'id': '4jL6WWKFDqCOPo2hC3VhSS',
#     'uri': 'spotify:track:4jL6WWKFDqCOPo2hC3VhSS',
#     'track_href': 'https://api.spotify.com/v1/tracks/4jL6WWKFDqCOPo2hC3VhSS',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4jL6WWKFDqCOPo2hC3VhSS',
#     'duration_ms': 240439,
#     'time_signature': 4}]},
#  {'Artist': 'Red Hot Chili Peppers',
#   'Title': 'Under the Bridge',
#   'Album': 'Greatest Hits',
#   'Audio Description': [{'danceability': 0.554,
#     'energy': 0.49,
#     'key': 4,
#     'loudness': -8.046,
#     'mode': 1,
#     'speechiness': 0.0457,
#     'acousticness': 0.0168,
#     'instrumentalness': 0.000534,
#     'liveness': 0.136,
#     'valence': 0.513,
#     'tempo': 84.275,
#     'type': 'audio_features',
#     'id': '23NPGXlSaIqWzvxIRhM2oG',
#     'uri': 'spotify:track:23NPGXlSaIqWzvxIRhM2oG',
#     'track_href': 'https://api.spotify.com/v1/tracks/23NPGXlSaIqWzvxIRhM2oG',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/23NPGXlSaIqWzvxIRhM2oG',
#     'duration_ms': 265507,
#     'time_signature': 4}]},
#  {'Artist': 'Rockabye Baby!',
#   'Title': 'Under the Bridge',
#   'Album': 'Lullaby Renditions of Red Hot Chili Peppers',
#   'Audio Description': [{'danceability': 0.704,
#     'energy': 0.06,
#     'key': 4,
#     'loudness': -21.087,
#     'mode': 1,
#     'speechiness': 0.0907,
#     'acousticness': 0.946,
#     'instrumentalness': 0.912,
#     'liveness': 0.109,
#     'valence': 0.791,
#     'tempo': 158.085,
#     'type': 'audio_features',
#     'id': '45VCZtguiCNu5zJ3YkmcWC',
#     'uri': 'spotify:track:45VCZtguiCNu5zJ3YkmcWC',
#     'track_href': 'https://api.spotify.com/v1/tracks/45VCZtguiCNu5zJ3YkmcWC',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/45VCZtguiCNu5zJ3YkmcWC',
#     'duration_ms': 259693,
#     'time_signature': 4}]},
#  {'Artist': 'Jack Harlow',
#   'Title': 'Churchill Downs (feat. Drake)',
#   'Album': 'Come Home The Kids Miss You',
#   'Audio Description': [{'danceability': 0.71,
#     'energy': 0.522,
#     'key': 11,
#     'loudness': -9.102,
#     'mode': 1,
#     'speechiness': 0.36,
#     'acousticness': 0.615,
#     'instrumentalness': 0,
#     'liveness': 0.11,
#     'valence': 0.37,
#     'tempo': 96.448,
#     'type': 'audio_features',
#     'id': '3EMp20j5E42MxfFbsEsIvD',
#     'uri': 'spotify:track:3EMp20j5E42MxfFbsEsIvD',
#     'track_href': 'https://api.spotify.com/v1/tracks/3EMp20j5E42MxfFbsEsIvD',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3EMp20j5E42MxfFbsEsIvD',
#     'duration_ms': 309327,
#     'time_signature': 4}]},
#  {'Artist': 'All Saints',
#   'Title': 'Under the Bridge',
#   'Album': 'All Saints',
#   'Audio Description': [{'danceability': 0.717,
#     'energy': 0.564,
#     'key': 6,
#     'loudness': -7.752,
#     'mode': 0,
#     'speechiness': 0.0551,
#     'acousticness': 0.0452,
#     'instrumentalness': 0.000464,
#     'liveness': 0.0897,
#     'valence': 0.728,
#     'tempo': 85.996,
#     'type': 'audio_features',
#     'id': '78M2x5ojbdTmUOpWrbijG3',
#     'uri': 'spotify:track:78M2x5ojbdTmUOpWrbijG3',
#     'track_href': 'https://api.spotify.com/v1/tracks/78M2x5ojbdTmUOpWrbijG3',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/78M2x5ojbdTmUOpWrbijG3',
#     'duration_ms': 301067,
#     'time_signature': 4}]},
#  {'Artist': 'Red Hot Chili Peppers',
#   'Title': 'Under the Bridge',
#   'Album': 'Blood Sugar Sex Magik',
#   'Audio Description': [{'danceability': 0.559,
#     'energy': 0.345,
#     'key': 4,
#     'loudness': -13.496,
#     'mode': 1,
#     'speechiness': 0.0459,
#     'acousticness': 0.0576,
#     'instrumentalness': 0.000105,
#     'liveness': 0.141,
#     'valence': 0.458,
#     'tempo': 84.581,
#     'type': 'audio_features',
#     'id': '5PclxRY6shIQzSKxxbdZso',
#     'uri': 'spotify:track:5PclxRY6shIQzSKxxbdZso',
#     'track_href': 'https://api.spotify.com/v1/tracks/5PclxRY6shIQzSKxxbdZso',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5PclxRY6shIQzSKxxbdZso',
#     'duration_ms': 264307,
#     'time_signature': 4}]},
#  {'Artist': 'Red Hot Chili Peppers',
#   'Title': 'Under The Bridge',
#   'Album': 'What Hits!?',
#   'Audio Description': [{'danceability': 0.475,
#     'energy': 0.401,
#     'key': 9,
#     'loudness': -11.672,
#     'mode': 1,
#     'speechiness': 0.0515,
#     'acousticness': 0.0285,
#     'instrumentalness': 5.8e-05,
#     'liveness': 0.115,
#     'valence': 0.475,
#     'tempo': 84.742,
#     'type': 'audio_features',
#     'id': '7C3fJ1q01IQ137IQTRwmVZ',
#     'uri': 'spotify:track:7C3fJ1q01IQ137IQTRwmVZ',
#     'track_href': 'https://api.spotify.com/v1/tracks/7C3fJ1q01IQ137IQTRwmVZ',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7C3fJ1q01IQ137IQTRwmVZ',
#     'duration_ms': 267560,
#     'time_signature': 4}]},
#  {'Artist': 'Sam Hunt',
#   'Title': 'Water Under The Bridge',
#   'Album': 'Water Under The Bridge',
#   'Audio Description': [{'danceability': 0.635,
#     'energy': 0.866,
#     'key': 5,
#     'loudness': -2.695,
#     'mode': 1,
#     'speechiness': 0.0473,
#     'acousticness': 0.0697,
#     'instrumentalness': 0,
#     'liveness': 0.0955,
#     'valence': 0.853,
#     'tempo': 133.889,
#     'type': 'audio_features',
#     'id': '4viFAHmivkYQKkwLvwKOgg',
#     'uri': 'spotify:track:4viFAHmivkYQKkwLvwKOgg',
#     'track_href': 'https://api.spotify.com/v1/tracks/4viFAHmivkYQKkwLvwKOgg',
#     'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4viFAHmivkYQKkwLvwKOgg',
#     'duration_ms': 169760,
#     'time_signature': 4}]}]

# %%
# make a dataframe from the list of songs created in the function above
df = pd.DataFrame(list_of_songs)

df
# Out:
#                   Artist                          Title  \
# 0  Red Hot Chili Peppers               Under the Bridge
# 1                   owlh               Under the Bridge
# 2                  Adele         Water Under the Bridge
# 3  Red Hot Chili Peppers               Under the Bridge
# 4         Rockabye Baby!               Under the Bridge
# 5            Jack Harlow  Churchill Downs (feat. Drake)
# 6             All Saints               Under the Bridge
# 7  Red Hot Chili Peppers               Under the Bridge
# 8  Red Hot Chili Peppers               Under The Bridge
# 9               Sam Hunt         Water Under The Bridge
#
#                                          Album  \
# 0       Blood Sugar Sex Magik (Deluxe Edition)
# 1                               cover to cover
# 2                                           25
# 3                                Greatest Hits
# 4  Lullaby Renditions of Red Hot Chili Peppers
# 5                  Come Home The Kids Miss You
# 6                                   All Saints
# 7                        Blood Sugar Sex Magik
# 8                                  What Hits!?
# 9                       Water Under The Bridge
#
#                                    Audio Description
# 0  [{'danceability': 0.559, 'energy': 0.345, 'key...
# 1  [{'danceability': 0.781, 'energy': 0.355, 'key...
# 2  [{'danceability': 0.59, 'energy': 0.833, 'key'...
# 3  [{'danceability': 0.554, 'energy': 0.49, 'key'...
# 4  [{'danceability': 0.704, 'energy': 0.06, 'key'...
# 5  [{'danceability': 0.71, 'energy': 0.522, 'key'...
# 6  [{'danceability': 0.717, 'energy': 0.564, 'key...
# 7  [{'danceability': 0.559, 'energy': 0.345, 'key...
# 8  [{'danceability': 0.475, 'energy': 0.401, 'key...
# 9  [{'danceability': 0.635, 'energy': 0.866, 'key...

# %% [markdown]
# As you can see, this DataFrame looks a bit off as the audio descriptions aren't expanded - all of the data is clumped together in one cell. Let's correct this, so we can see each audio feature as an individual column.

# %%
# quick function we can <<<<<<<use to select only the 1st item 
# this can also be done simply with [0], but we wanted to show you how you can incorporate a custom function into your work

def first_value (x):
    return x[0]

# making a DataFrame from the audio features of the songs in list_of_songs
df_audio_features = pd.json_normalize(df['Audio Description'].apply(first_value))

df_audio_features
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.559   0.345    4   -13.496     1       0.0459        0.0576
# 1         0.781   0.355    9    -8.158     1       0.0376        0.4710
# 2         0.590   0.833    5    -6.503     0       0.0615        0.0142
# 3         0.554   0.490    4    -8.046     1       0.0457        0.0168
# 4         0.704   0.060    4   -21.087     1       0.0907        0.9460
# 5         0.710   0.522   11    -9.102     1       0.3600        0.6150
# 6         0.717   0.564    6    -7.752     0       0.0551        0.0452
# 7         0.559   0.345    4   -13.496     1       0.0459        0.0576
# 8         0.475   0.401    9   -11.672     1       0.0515        0.0285
# 9         0.635   0.866    5    -2.695     1       0.0473        0.0697
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000105    0.1410    0.458   84.581  audio_features
# 1          0.878000    0.1250    0.363  131.978  audio_features
# 2          0.000005    0.1050    0.538   94.963  audio_features
# 3          0.000534    0.1360    0.513   84.275  audio_features
# 4          0.912000    0.1090    0.791  158.085  audio_features
# 5          0.000000    0.1100    0.370   96.448  audio_features
# 6          0.000464    0.0897    0.728   85.996  audio_features
# 7          0.000105    0.1410    0.458   84.581  audio_features
# 8          0.000058    0.1150    0.475   84.742  audio_features
# 9          0.000000    0.0955    0.853  133.889  audio_features
#
#                        id                                   uri  \
# 0  3d9DChrdc6BOeFsbrZ3Is0  spotify:track:3d9DChrdc6BOeFsbrZ3Is0
# 1  1AyRpRvLwUwkXwGGuNZHmN  spotify:track:1AyRpRvLwUwkXwGGuNZHmN
# 2  4jL6WWKFDqCOPo2hC3VhSS  spotify:track:4jL6WWKFDqCOPo2hC3VhSS
# 3  23NPGXlSaIqWzvxIRhM2oG  spotify:track:23NPGXlSaIqWzvxIRhM2oG
# 4  45VCZtguiCNu5zJ3YkmcWC  spotify:track:45VCZtguiCNu5zJ3YkmcWC
# 5  3EMp20j5E42MxfFbsEsIvD  spotify:track:3EMp20j5E42MxfFbsEsIvD
# 6  78M2x5ojbdTmUOpWrbijG3  spotify:track:78M2x5ojbdTmUOpWrbijG3
# 7  5PclxRY6shIQzSKxxbdZso  spotify:track:5PclxRY6shIQzSKxxbdZso
# 8  7C3fJ1q01IQ137IQTRwmVZ  spotify:track:7C3fJ1q01IQ137IQTRwmVZ
# 9  4viFAHmivkYQKkwLvwKOgg  spotify:track:4viFAHmivkYQKkwLvwKOgg
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3d9DChrdc6BO...
# 1  https://api.spotify.com/v1/tracks/1AyRpRvLwUwk...
# 2  https://api.spotify.com/v1/tracks/4jL6WWKFDqCO...
# 3  https://api.spotify.com/v1/tracks/23NPGXlSaIqW...
# 4  https://api.spotify.com/v1/tracks/45VCZtguiCNu...
# 5  https://api.spotify.com/v1/tracks/3EMp20j5E42M...
# 6  https://api.spotify.com/v1/tracks/78M2x5ojbdTm...
# 7  https://api.spotify.com/v1/tracks/5PclxRY6shIQ...
# 8  https://api.spotify.com/v1/tracks/7C3fJ1q01IQ1...
# 9  https://api.spotify.com/v1/tracks/4viFAHmivkYQ...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3d9D...       264307
# 1  https://api.spotify.com/v1/audio-analysis/1AyR...       244196
# 2  https://api.spotify.com/v1/audio-analysis/4jL6...       240439
# 3  https://api.spotify.com/v1/audio-analysis/23NP...       265507
# 4  https://api.spotify.com/v1/audio-analysis/45VC...       259693
# 5  https://api.spotify.com/v1/audio-analysis/3EMp...       309327
# 6  https://api.spotify.com/v1/audio-analysis/78M2...       301067
# 7  https://api.spotify.com/v1/audio-analysis/5Pcl...       264307
# 8  https://api.spotify.com/v1/audio-analysis/7C3f...       267560
# 9  https://api.spotify.com/v1/audio-analysis/4viF...       169760
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
# 5               4
# 6               4
# 7               4
# 8               4
# 9               4

# %%
# merge the expanded audio features with the original DataFrame
new_df = pd.merge(df, df_audio_features, left_index=True, right_index=True)

# drop the old ugly column where all the audio features are clumped together
new_df.drop('Audio Description', axis=1, inplace=True)

new_df
# Out:
#                   Artist                          Title  \
# 0  Red Hot Chili Peppers               Under the Bridge
# 1                   owlh               Under the Bridge
# 2                  Adele         Water Under the Bridge
# 3  Red Hot Chili Peppers               Under the Bridge
# 4         Rockabye Baby!               Under the Bridge
# 5            Jack Harlow  Churchill Downs (feat. Drake)
# 6             All Saints               Under the Bridge
# 7  Red Hot Chili Peppers               Under the Bridge
# 8  Red Hot Chili Peppers               Under The Bridge
# 9               Sam Hunt         Water Under The Bridge
#
#                                          Album  danceability  energy  key  \
# 0       Blood Sugar Sex Magik (Deluxe Edition)         0.559   0.345    4
# 1                               cover to cover         0.781   0.355    9
# 2                                           25         0.590   0.833    5
# 3                                Greatest Hits         0.554   0.490    4
# 4  Lullaby Renditions of Red Hot Chili Peppers         0.704   0.060    4
# 5                  Come Home The Kids Miss You         0.710   0.522   11
# 6                                   All Saints         0.717   0.564    6
# 7                        Blood Sugar Sex Magik         0.559   0.345    4
# 8                                  What Hits!?         0.475   0.401    9
# 9                       Water Under The Bridge         0.635   0.866    5
#
#    loudness  mode  speechiness  acousticness  ...  liveness  valence    tempo  \
# 0   -13.496     1       0.0459        0.0576  ...    0.1410    0.458   84.581
# 1    -8.158     1       0.0376        0.4710  ...    0.1250    0.363  131.978
# 2    -6.503     0       0.0615        0.0142  ...    0.1050    0.538   94.963
# 3    -8.046     1       0.0457        0.0168  ...    0.1360    0.513   84.275
# 4   -21.087     1       0.0907        0.9460  ...    0.1090    0.791  158.085
# 5    -9.102     1       0.3600        0.6150  ...    0.1100    0.370   96.448
# 6    -7.752     0       0.0551        0.0452  ...    0.0897    0.728   85.996
# 7   -13.496     1       0.0459        0.0576  ...    0.1410    0.458   84.581
# 8   -11.672     1       0.0515        0.0285  ...    0.1150    0.475   84.742
# 9    -2.695     1       0.0473        0.0697  ...    0.0955    0.853  133.889
#
#              type                      id  \
# 0  audio_features  3d9DChrdc6BOeFsbrZ3Is0
# 1  audio_features  1AyRpRvLwUwkXwGGuNZHmN
# 2  audio_features  4jL6WWKFDqCOPo2hC3VhSS
# 3  audio_features  23NPGXlSaIqWzvxIRhM2oG
# 4  audio_features  45VCZtguiCNu5zJ3YkmcWC
# 5  audio_features  3EMp20j5E42MxfFbsEsIvD
# 6  audio_features  78M2x5ojbdTmUOpWrbijG3
# 7  audio_features  5PclxRY6shIQzSKxxbdZso
# 8  audio_features  7C3fJ1q01IQ137IQTRwmVZ
# 9  audio_features  4viFAHmivkYQKkwLvwKOgg
#
#                                     uri  \
# 0  spotify:track:3d9DChrdc6BOeFsbrZ3Is0
# 1  spotify:track:1AyRpRvLwUwkXwGGuNZHmN
# 2  spotify:track:4jL6WWKFDqCOPo2hC3VhSS
# 3  spotify:track:23NPGXlSaIqWzvxIRhM2oG
# 4  spotify:track:45VCZtguiCNu5zJ3YkmcWC
# 5  spotify:track:3EMp20j5E42MxfFbsEsIvD
# 6  spotify:track:78M2x5ojbdTmUOpWrbijG3
# 7  spotify:track:5PclxRY6shIQzSKxxbdZso
# 8  spotify:track:7C3fJ1q01IQ137IQTRwmVZ
# 9  spotify:track:4viFAHmivkYQKkwLvwKOgg
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3d9DChrdc6BO...
# 1  https://api.spotify.com/v1/tracks/1AyRpRvLwUwk...
# 2  https://api.spotify.com/v1/tracks/4jL6WWKFDqCO...
# 3  https://api.spotify.com/v1/tracks/23NPGXlSaIqW...
# 4  https://api.spotify.com/v1/tracks/45VCZtguiCNu...
# 5  https://api.spotify.com/v1/tracks/3EMp20j5E42M...
# 6  https://api.spotify.com/v1/tracks/78M2x5ojbdTm...
# 7  https://api.spotify.com/v1/tracks/5PclxRY6shIQ...
# 8  https://api.spotify.com/v1/tracks/7C3fJ1q01IQ1...
# 9  https://api.spotify.com/v1/tracks/4viFAHmivkYQ...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3d9D...      264307
# 1  https://api.spotify.com/v1/audio-analysis/1AyR...      244196
# 2  https://api.spotify.com/v1/audio-analysis/4jL6...      240439
# 3  https://api.spotify.com/v1/audio-analysis/23NP...      265507
# 4  https://api.spotify.com/v1/audio-analysis/45VC...      259693
# 5  https://api.spotify.com/v1/audio-analysis/3EMp...      309327
# 6  https://api.spotify.com/v1/audio-analysis/78M2...      301067
# 7  https://api.spotify.com/v1/audio-analysis/5Pcl...      264307
# 8  https://api.spotify.com/v1/audio-analysis/7C3f...      267560
# 9  https://api.spotify.com/v1/audio-analysis/4viF...      169760
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
# 5               4
# 6               4
# 7               4
# 8               4
# 9               4
#
# [10 rows x 21 columns]

# %% [markdown]
# If you like a challenge and want to have a go at testing what you've just learnt. Follow the steps below and see if you can make a DataFrame similar to above with expanded audio features. This time though, do it for a playlist of your choosing on spotify. Then see if you can expand it to include the songs from multiple playlists.
#
# Try not to look at the solution, but we've included it below in case you get stuck
#
# ### Collect a big dataframe of songs with their audio features
#
# - Start by looking for a playlist on spotify (it does not have to be your playlist), and copy its url.
#
# - Extract the audio features for each song on your playlist.
#
# - Now collect the link of many playlists and do the same for all of them.
#
# - Structure the information as a dataframe where each row is a song and the columns are audio features.

# %%
list_of_songs = []

def song_features(human_song_title):
    # search for the song title you enter into the function, limited to the first 10 results
    results = sp.search(q=human_song_title, limit = 10)['tracks']['items']
    # create a loop, so we only select the parts of the json we need
    for i in results:
        # empty dictionary to be filled with the information below
        track_dict = {}
        # add the key artist and a corresponding value to the dictionary
        track_dict['Artist'] = i['artists'][0]['name']
        # add the key title and the corresponding value to the dictionary
        track_dict['Title'] = i['name'] 
        # add the key album and the corresponding value to the dictionary
        track_dict['Album'] = i['album']['name']
        # add the key audio description and the corresponding value to the dictionary
        track_dict['Audio Description'] = sp.audio_features(i['id'])
        # add the dictionary to the list list_of_songs
        list_of_songs.append(track_dict)
    # output list_of_songs 
    return list_of_songs

# call the function with a song to test
song_features("Under the Bridge")

# %% [markdown]
# #### Solution

# %%
list_of_playlists = ["spotify:playlist:2zjepkjZxLpeIBlvPCWIHl",
                    "spotify:playlist:0ce6Rmxf7QXroqa1wzjWY8"]

track_list = []
for i in list_of_playlists:
    individual_playlist = sp.user_playlist_tracks(user="spotify", playlist_id=i)['items']
    for j in individual_playlist:
        track_dict = {}
        track_dict["Artist"] = j['track']['artists'][0]['name']
        track_dict["Title"] = j['track']['name']
        track_dict["Album"] = j['track']['album']['name']
        track_dict["Audio Description"] = sp.audio_features(j['track']['id'])
        track_list.append(track_dict)

print(track_list)
# Out:
# [{'Artist': 'James Blake', 'Title': 'Words That We Both Know', 'Album': '200 Press EP', 'Audio Description': [{'danceability': 0.5, 'energy': 0.439, 'key': 7, 'loudness': -9.207, 'mode': 0, 'speechiness': 0.107, 'acousticness': 0.927, 'instrumentalness': 0.000445, 'liveness': 0.281, 'valence': 0.42, 'tempo': 62.058, 'type': 'audio_features', 'id': '4BZtAKMwi4aM18Zr2mTIgt', 'uri': 'spotify:track:4BZtAKMwi4aM18Zr2mTIgt', 'track_href': 'https://api.spotify.com/v1/tracks/4BZtAKMwi4aM18Zr2mTIgt', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4BZtAKMwi4aM18Zr2mTIgt', 'duration_ms': 63025, 'time_signature': 5}]}, {'Artist': 'Gene Wilder', 'Title': 'Pure Imagination - From "Willy Wonka & The Chocolate Factory" Soundtrack', 'Album': 'Willy Wonka & The Chocolate Factory', 'Audio Description': [{'danceability': 0.251, 'energy': 0.115, 'key': 10, 'loudness': -20.223, 'mode': 0, 'speechiness': 0.038, 'acousticness': 0.695, 'instrumentalness': 2.11e-05, 'liveness': 0.617, 'valence': 0.116, 'tempo': 70.645, 'type': 'audio_features', 'id': '4f4HLo6L9CJNhD4mEYxrCL', 'uri': 'spotify:track:4f4HLo6L9CJNhD4mEYxrCL', 'track_href': 'https://api.spotify.com/v1/tracks/4f4HLo6L9CJNhD4mEYxrCL', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4f4HLo6L9CJNhD4mEYxrCL', 'duration_ms': 260227, 'time_signature': 4}]}, {'Artist': 'Bob Dorough', 'Title': 'Polka Dots and Moonbeams', 'Album': 'Devil May Care', 'Audio Description': [{'danceability': 0.58, 'energy': 0.133, 'key': 0, 'loudness': -18.177, 'mode': 0, 'speechiness': 0.0962, 'acousticness': 0.795, 'instrumentalness': 0.0172, 'liveness': 0.18, 'valence': 0.211, 'tempo': 57.658, 'type': 'audio_features', 'id': '2wy2ScXvlpguDeo4NnwvOm', 'uri': 'spotify:track:2wy2ScXvlpguDeo4NnwvOm', 'track_href': 'https://api.spotify.com/v1/tracks/2wy2ScXvlpguDeo4NnwvOm', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2wy2ScXvlpguDeo4NnwvOm', 'duration_ms': 205360, 'time_signature': 3}]}, {'Artist': 'Isaiah Rashad', 'Title': 'R.I.P. Kevin Miller', 'Album': 'Cilvia Demo', 'Audio Description': [{'danceability': 0.703, 'energy': 0.835, 'key': 8, 'loudness': -4.456, 'mode': 0, 'speechiness': 0.27, 'acousticness': 0.227, 'instrumentalness': 1.4e-05, 'liveness': 0.135, 'valence': 0.602, 'tempo': 136.158, 'type': 'audio_features', 'id': '6zSwnPvoqQ2bzvYMlt3u4u', 'uri': 'spotify:track:6zSwnPvoqQ2bzvYMlt3u4u', 'track_href': 'https://api.spotify.com/v1/tracks/6zSwnPvoqQ2bzvYMlt3u4u', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6zSwnPvoqQ2bzvYMlt3u4u', 'duration_ms': 229219, 'time_signature': 4}]}, {'Artist': 'Jon Brion', 'Title': 'Phone Call - From "Eternal Sunshine of the Spotless Mind"/Score', 'Album': 'Eternal Sunshine Of The Spotless Mind', 'Audio Description': [{'danceability': 0.498, 'energy': 0.377, 'key': 1, 'loudness': -19.858, 'mode': 1, 'speechiness': 0.0474, 'acousticness': 0.982, 'instrumentalness': 0.938, 'liveness': 0.107, 'valence': 0.545, 'tempo': 126.252, 'type': 'audio_features', 'id': '7LYeytL8R2fuqnsW1s0k86', 'uri': 'spotify:track:7LYeytL8R2fuqnsW1s0k86', 'track_href': 'https://api.spotify.com/v1/tracks/7LYeytL8R2fuqnsW1s0k86', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7LYeytL8R2fuqnsW1s0k86', 'duration_ms': 62600, 'time_signature': 4}]}, {'Artist': 'Action Bronson', 'Title': 'Terry', 'Album': 'Mr. Wonderful', 'Audio Description': [{'danceability': 0.376, 'energy': 0.62, 'key': 1, 'loudness': -5.84, 'mode': 1, 'speechiness': 0.367, 'acousticness': 0.707, 'instrumentalness': 0, 'liveness': 0.107, 'valence': 0.0477, 'tempo': 87.538, 'type': 'audio_features', 'id': '6bj42Hzr3RErxhfgSTdSx6', 'uri': 'spotify:track:6bj42Hzr3RErxhfgSTdSx6', 'track_href': 'https://api.spotify.com/v1/tracks/6bj42Hzr3RErxhfgSTdSx6', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6bj42Hzr3RErxhfgSTdSx6', 'duration_ms': 289493, 'time_signature': 4}]}, {'Artist': 'Benny Sings', 'Title': 'Realize', 'Album': 'Art', 'Audio Description': [{'danceability': 0.829, 'ene ...

# %%
playlist_df = pd.DataFrame(track_list)

# %%
def first_value (x):
    return x[0]

# %%
df_a_f = pd.json_normalize(playlist_df['Audio Description'].apply(first_value))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Audio Description'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-120-ddf421e10446> in <module>
# ----> 1 df_a_f = pd.json_normalize(playlist_df['Audio Description'].apply(first_value))
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Audio Description'

# %%
df_audio_features = pd.json_normalize(df['Audio Description'].apply(first_value))

df_audio_features

# %%
new_playlist_df = pd.merge(playlist_df, df_a_f, left_index=True, right_index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-daf837f4b091> in <module>
# ----> 1 new_playlist_df = pd.merge(playlist_df, df_a_f, left_index=True, right_index=True)
#
# NameError: name 'df_a_f' is not defined

# %%
new_playlist_df.drop('Audio Description', axis=1, inplace=True)

# %%
new_playlist_df
