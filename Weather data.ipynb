# %% [markdown]
# import modules

# %%
import requests
import pandas as pd

# %% [markdown]
# getting api key

# %%
api_key='83fa26bdfdf0de553c224eb0faf87136'

# %% [markdown]
# get the coordinates of the city

# %%
city= "berlin"
link=f"https://api.openweathermap.org/data/2.5/forecast?q={city}&appid={api_key}&units=metric"
print(link)
# Out:
# https://api.openweathermap.org/data/2.5/forecast?q=berlin&appid=83fa26bdfdf0de553c224eb0faf87136&units=metric

# %%
response= requests.get(link)#parsing the Json
data=response.json()
print(data)
# Out:
# {'cod': '200', 'message': 0, 'cnt': 40, 'list': [{'dt': 1664917200, 'main': {'temp': 12.41, 'feels_like': 11.85, 'temp_min': 12.41, 'temp_max': 12.62, 'pressure': 1010, 'sea_level': 1010, 'grnd_level': 1015, 'humidity': 82, 'temp_kf': -0.21}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'clouds': {'all': 0}, 'wind': {'speed': 3.08, 'deg': 199, 'gust': 8.86}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2022-10-04 21:00:00'}, {'dt': 1664928000, 'main': {'temp': 12.17, 'feels_like': 11.51, 'temp_min': 11.7, 'temp_max': 12.17, 'pressure': 1013, 'sea_level': 1013, 'grnd_level': 1014, 'humidity': 79, 'temp_kf': 0.47}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'clouds': {'all': 29}, 'wind': {'speed': 3.12, 'deg': 204, 'gust': 9.28}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2022-10-05 00:00:00'}, {'dt': 1664938800, 'main': {'temp': 11.87, 'feels_like': 11.07, 
# ...

# %% [markdown]
# getting keys

# %%
len(data)
# Out:
# 5

# %%
data.keys()
# Out:
# dict_keys(['cod', 'message', 'cnt', 'list', 'city'])

# %% [markdown]
# getting name and latitude and longitude

# %%
city= "berlin"
link=f"https://api.openweathermap.org/data/2.5/forecast?q={city}&appid={api_key}&units=metric"
#print(link)
response= requests.get(link)#parsing the Json
data=response.json()
#print(data)
name= data['city']['name']
lat=data['city']['coord']['lat']
lon= data['city']['coord']['lon']
print(name)
print(lat)
print(lon)
# Out:
# Berlin
# 52.5244
# 13.4105

# %%
temp=[]
humidity=[]
wind_speed=[]
date=[]
for i in data['list']:
  temp.append(i['main']['temp_max'])
  humidity.append(i['main']['humidity'])
  wind_speed.append(i['wind']['speed'])
  date.append(i['dt_txt'])
print(temp)
print(humidity)
print(wind_speed)
print(date)
# Out:
# [12.62, 12.1, 11.83, 11.57, 16.05, 19.68, 19.76, 16.47, 15.38, 14.52, 14.18, 15.64, 16.25, 17.82, 17.24, 13.8, 12.05, 10.73, 9.6, 9.35, 14.62, 18.27, 18.12, 13.98, 12.42, 11.55, 10.23, 10.21, 14.98, 11.94, 14.24, 11.12, 9.85, 8.9, 7.92, 7.5, 12.4, 15.54, 15.64, 12.52]
# [82, 79, 75, 71, 53, 40, 44, 58, 67, 74, 78, 72, 57, 42, 44, 56, 63, 69, 73, 71, 49, 39, 37, 47, 52, 62, 76, 74, 58, 83, 65, 75, 78, 81, 83, 83, 60, 45, 43, 52]
# [3.08, 3.12, 3.22, 3.31, 4.47, 4.91, 4.72, 4.13, 4.64, 4.37, 4.59, 6.25, 7.26, 6.24, 4.66, 3.18, 2.4, 2.06, 2.1, 2.22, 3.21, 3.74, 3.47, 2.3, 2.48, 2.65, 2.54, 2.97, 5.3, 4.17, 4.93, 3.54, 4.04, 3.93, 3.31, 3.17, 4.05, 3.95, 3, 1.66]
# ...

# %%
response.json()

# %%
from typing_extensions import dataclass_transform
#'excluding minutely and hourly'
exclude="minutely,hourly"
lat=44.34
lon=10.99
url=f'https://api.openweathermap.org/data/2.5/forecast?lat={lat}&lon={lon}&exclude={exclude}&appid={api_key}'
print(url)
req2=requests.get(url)
data2=req2.json()
print(data2)
# Out:
# https://api.openweathermap.org/data/2.5/forecast?lat=44.34&lon=10.99&exclude=minutely,hourly&appid=83fa26bdfdf0de553c224eb0faf87136
# ...

# %% [markdown]
# All in one function

# %%
msg='Enter the city name:'
city= input(msg)
link=f"https://api.openweathermap.org/data/2.5/forecast?q={city}&appid={api_key}&units=metric"
#print(link)
response= requests.get(link)#parsing the Json
data=response.json()
#print(data)
name= data['city']['name']
lat=data['city']['coord']['lat']
lon= data['city']['coord']['lon']
print(name)
print(lat)
print(lon)
# Out:
# Enter the city name:berlin
# Berlin
# 52.5244
# 13.4105

# %%
msg='Enter the city name:'
city= input(msg)
link=f"https://api.openweathermap.org/data/2.5/forecast?q={city}&appid={api_key}&units=metric"
#print(link)
response= requests.get(link)#parsing the Json
data=response.json()
#print(data)
name= data['city']['name']
lat=data['city']['coord']['lat']
lon= data['city']['coord']['lon']
print(name)
print(lat)
print(lon)
temp=[]
humidity=[]
wind_speed=[]
date=[]
for i in data['list']:
  dict={}
  dict["Temperature"]=temp.append(i['main']['temp_max'])
  dict["Humidity"]=humidity.append(i['main']['humidity'])
  dict["Wind_speed"]=wind_speed.append(i['wind']['speed'])
  dict["date"]=date.append(i['dt_txt'])
print("Temperature:" , temp)
print("Humidity:",humidity)
print("Wind_speed:",wind_speed)
print("date:",date)
# Out:
# Enter the city name:milan
# Milan
# 45.4643
# 9.1895
# Temperature: [16.08, 15.84, 15.27, 18.94, 22.38, 22.83, 20.11, 18.65, 17.56, 16.6, 16.07, 20.22, 23.65, 23.9, 20.84, 19.18, 17.97, 16.95, 16.42, 20.81, 24.48, 24.34, 20.9, 19.3, 17.86, 16.84, 16.27, 20.45, 22.98, 23.05, 20.78, 19.64, 18.25, 17.14, 16.18, 19.12, 21.74, 21.87, 18.73, 17.39]
# Humidity: [87, 84, 83, 65, 53, 50, 62, 69, 73, 77, 78, 60, 48, 48, 63, 70, 72, 75, 76, 57, 41, 40, 53, 58, 63, 67, 70, 54, 45, 44, 52, 58, 64, 69, 78, 69, 57, 55, 69, 74]
# Wind_speed: [1.71, 1.25, 0.96, 1.3, 0.46, 0.76, 0.85, 0.38, 0.28, 0.72, 0.59, 0.58, 0.79, 1.73, 1.74, 1.75, 1.12, 0.56, 0.48, 0.98, 0.3, 1.65, 1.46, 0.77, 0.74, 0.25, 0.72, 0.96, 1.41, 0.75, 1.39, 0.59, 0.62, 1.86, 2.51, 2.4, 2.77, 3.11, 1.9, 1.72]
# ...

# %%
df=pd.DataFrame(list)
